# %% [markdown]
# # Introduction to the Planner
#
# The Planner is one of the fundamental concepts of the Semantic Kernel.
#
# It makes use of the collection of native and semantic functions that have been registered to the kernel and using AI, will formulate a plan to execute the given ask.
#
# From our own testing, planner works best with more powerful models like `gpt4` but sometimes you might get working plans with cheaper models like `gpt-35-turbo`. We encourage you to implement your own versions of the planner and use different models that fit your user needs.
#
# Read more about planner [here](https://aka.ms/sk/concepts/planner).

# %% [markdown]
# Import Semantic Kernel SDK from pypi.org

# %%
# Note: if using a Poetry virtual environment, do not run this cell
# %pip install semantic-kernel==1.2.0
# Out:
# Requirement already satisfied: semantic-kernel==1.2.0 in c:\users\johealy\.conda\envs\pytorch_env\lib\site-packages (1.2.0)
# Requirement already satisfied: aiohttp<4.0,>=3.8 in c:\users\johealy\.conda\envs\pytorch_env\lib\site-packages (from semantic-kernel==1.2.0) (3.9.5)
# Requirement already satisfied: defusedxml<0.8.0,>=0.7.1 in c:\users\johealy\.conda\envs\pytorch_env\lib\site-packages (from semantic-kernel==1.2.0) (0.7.1)
# Requirement already satisfied: jinja2<4.0.0,>=3.1.3 in c:\users\johealy\appdata\roaming\python\python311\site-packages (from semantic-kernel==1.2.0) (3.1.3)
# Requirement already satisfied: nest-asyncio<2.0.0,>=1.6.0 in c:\users\johealy\.conda\envs\pytorch_env\lib\site-packages (from semantic-kernel==1.2.0) (1.6.0)
# Requirement already satisfied: numpy>=1.25 in c:\users\johealy\.conda\envs\pytorch_env\lib\site-packages (from semantic-kernel==1.2.0) (2.0.0)
# Requirement already satisfied: openai>=1.0 in c:\users\johealy\.conda\envs\pytorch_env\lib\site-packages (from semantic-kernel==1.2.0) (1.35.13)
# Requirement already satisfied: openapi_core<0.20,>=0.18 in c:\users\johealy\.conda\envs\pytorch_env\lib\site-packages (from semantic-kernel==1.2.0) (0.19.2)
# Requirement already satisfied: prance<24.0.0.0,>=23.6.21.0 in c:\users\johealy\.conda\envs\pytorch_env\lib\site-packages (from semantic-kernel==1.2.0) (23.6.21.0)
# Requirement already satisfied: pybars4<0.10.0,>=0.9.13 in c:\users\johealy\.conda\envs\pytorch_env\lib\site-packages (from semantic-kernel==1.2.0) (0.9.13)
# Requirement already satisfied: pydantic<3,>=2 in c:\users\johealy\.conda\envs\pytorch_env\lib\site-packages (from semantic-kernel==1.2.0) (2.8.2)
# Requirement already satisfied: pydantic-settings<3,>=2 in c:\users\johealy\.conda\envs\pytorch_env\lib\site-packages (from semantic-kernel==1.2.0) (2.3.4)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\johealy\.conda\envs\pytorch_env\lib\site-packages (from aiohttp<4.0,>=3.8->semantic-kernel==1.2.0) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\johealy\.conda\envs\pytorch_env\lib\site-packages (from aiohttp<4.0,>=3.8->semantic-kernel==1.2.0) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\johealy\.conda\envs\pytorch_env\lib\site-packages (from aiohttp<4.0,>=3.8->semantic-kernel==1.2.0) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\johealy\.conda\envs\pytorch_env\lib\site-packages (from aiohttp<4.0,>=3.8->semantic-kernel==1.2.0) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in c:\users\johealy\.conda\envs\pytorch_env\lib\site-packages (from aiohttp<4.0,>=3.8->semantic-kernel==1.2.0) (1.9.4)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\johealy\appdata\roaming\python\python311\site-packages (from jinja2<4.0.0,>=3.1.3->semantic-kernel==1.2.0) (2.1.5)
# Requirement already satisfied: anyio<5,>=3.5.0 in c:\users\johealy\.conda\envs\pytorch_env\lib\site-packages (from openai>=1.0->semantic-kernel==1.2.0) (4.3.0)
# Requirement already satisfied: distro<2,>=1.7.0 in c:\users\johealy\.conda\envs\pytorch_env\lib\site-packages (from openai>=1.0->semantic-kernel==1.2.0) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\johealy\.conda\envs\pytorch_env\lib\site-packages (from openai>=1.0->semantic-kernel==1.2.0) (0.24.1)
# Requirement already satisfied: sniffio in c:\users\johealy\.conda\envs\pytorch_env\lib\site-packages (from openai>=1.0->semantic-kernel==1.2.0) (1.3.1)
# Requirement already satisfied: tqdm>4 in c:\users\johealy\.conda\envs\pytorch_env\lib\site-packages (from openai>=1.0->semantic-kernel==1.2.0) (4.66.4)
# Requirement already satisfied: typing-extensions<5,>=4.7 in c:\users\johealy\.conda\envs\pytorch_env\lib\site-packages (from openai>=1.0->semantic-kernel==1.2.0) (4.12.2)
# Requirement already satisfied: isodate in c:\users\johealy\.conda\envs\pytorch_env\lib\site-packages (from openapi_core<0.20,>=0.18->semantic-kernel==1.2.0) (0.6.1)
# Requirement already satisfied: jsonschema<5.0.0,>=4.18.0 in c:\users\johealy\.conda\envs\pytorch_env\lib\site-packages (from openapi_core<0.20,>=0.18->semantic-kernel==1.2.0) (4.23.0)
# Requirement already satisfied: jsonschema-path<0.4.0,>=0.3.1 in c:\users\johealy\.conda\envs\pytorch_env\lib\site-packages (from openapi_core<0.20,>=0.18->semantic-kernel==1.2.0) (0.3.3)
# Requirement already satisfied: more-itertools in c:\users\johealy\.conda\envs\pytorch_env\lib\site-packages (from openapi_core<0.20,>=0.18->semantic-kernel==1.2.0) (10.3.0)
# Requirement already satisfied: openapi-schema-validator<0.7.0,>=0.6.0 in c:\users\johealy\.conda\envs\pytorch_env\lib\site-packages (from openapi_core<0.20,>=0.18->semantic-kernel==1.2.0) (0.6.2)
# Requirement already satisfied: openapi-spec-validator<0.8.0,>=0.7.1 in c:\users\johealy\.conda\envs\pytorch_env\lib\site-packages (from openapi_core<0.20,>=0.18->semantic-kernel==1.2.0) (0.7.1)
# Requirement already satisfied: parse in c:\users\johealy\.conda\envs\pytorch_env\lib\site-packages (from openapi_core<0.20,>=0.18->semantic-kernel==1.2.0) (1.20.2)
# Requirement already satisfied: werkzeug in c:\users\johealy\.conda\envs\pytorch_env\lib\site-packages (from openapi_core<0.20,>=0.18->semantic-kernel==1.2.0) (3.0.3)
# Requirement already satisfied: chardet>=3.0 in c:\users\johealy\.conda\envs\pytorch_env\lib\site-packages (from prance<24.0.0.0,>=23.6.21.0->semantic-kernel==1.2.0) (5.2.0)
# Requirement already satisfied: ruamel.yaml>=0.17.10 in c:\users\johealy\.conda\envs\pytorch_env\lib\site-packages (from prance<24.0.0.0,>=23.6.21.0->semantic-kernel==1.2.0) (0.18.6)
# Requirement already satisfied: requests>=2.25 in c:\users\johealy\.conda\envs\pytorch_env\lib\site-packages (from prance<24.0.0.0,>=23.6.21.0->semantic-kernel==1.2.0) (2.31.0)
# Requirement already satisfied: six~=1.15 in c:\users\johealy\.conda\envs\pytorch_env\lib\site-packages (from prance<24.0.0.0,>=23.6.21.0->semantic-kernel==1.2.0) (1.16.0)
# Requirement already satisfied: packaging>=21.3 in c:\users\johealy\appdata\roaming\python\python311\site-packages (from prance<24.0.0.0,>=23.6.21.0->semantic-kernel==1.2.0) (23.2)
# Requirement already satisfied: PyMeta3>=0.5.1 in c:\users\johealy\.conda\envs\pytorch_env\lib\site-packages (from pybars4<0.10.0,>=0.9.13->semantic-kernel==1.2.0) (0.5.1)
# Requirement already satisfied: annotated-types>=0.4.0 in c:\users\johealy\.conda\envs\pytorch_env\lib\site-packages (from pydantic<3,>=2->semantic-kernel==1.2.0) (0.7.0)
# Requirement already satisfied: pydantic-core==2.20.1 in c:\users\johealy\.conda\envs\pytorch_env\lib\site-packages (from pydantic<3,>=2->semantic-kernel==1.2.0) (2.20.1)
# Requirement already satisfied: python-dotenv>=0.21.0 in c:\users\johealy\.conda\envs\pytorch_env\lib\site-packages (from pydantic-settings<3,>=2->semantic-kernel==1.2.0) (1.0.1)
# Requirement already satisfied: idna>=2.8 in c:\users\johealy\.conda\envs\pytorch_env\lib\site-packages (from anyio<5,>=3.5.0->openai>=1.0->semantic-kernel==1.2.0) (3.7)
# Requirement already satisfied: certifi in c:\users\johealy\.conda\envs\pytorch_env\lib\site-packages (from httpx<1,>=0.23.0->openai>=1.0->semantic-kernel==1.2.0) (2024.2.2)
# Requirement already satisfied: httpcore<0.18.0,>=0.15.0 in c:\users\johealy\.conda\envs\pytorch_env\lib\site-packages (from httpx<1,>=0.23.0->openai>=1.0->semantic-kernel==1.2.0) (0.17.3)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\johealy\.conda\envs\pytorch_env\lib\site-packages (from jsonschema<5.0.0,>=4.18.0->openapi_core<0.20,>=0.18->semantic-kernel==1.2.0) (2023.12.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\johealy\.conda\envs\pytorch_env\lib\site-packages (from jsonschema<5.0.0,>=4.18.0->openapi_core<0.20,>=0.18->semantic-kernel==1.2.0) (0.35.1)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\johealy\.conda\envs\pytorch_env\lib\site-packages (from jsonschema<5.0.0,>=4.18.0->openapi_core<0.20,>=0.18->semantic-kernel==1.2.0) (0.19.0)
# Requirement already satisfied: PyYAML>=5.1 in c:\users\johealy\.conda\envs\pytorch_env\lib\site-packages (from jsonschema-path<0.4.0,>=0.3.1->openapi_core<0.20,>=0.18->semantic-kernel==1.2.0) (6.0.1)
# Requirement already satisfied: pathable<0.5.0,>=0.4.1 in c:\users\johealy\.conda\envs\pytorch_env\lib\site-packages (from jsonschema-path<0.4.0,>=0.3.1->openapi_core<0.20,>=0.18->semantic-kernel==1.2.0) (0.4.3)
# Requirement already satisfied: rfc3339-validator in c:\users\johealy\.conda\envs\pytorch_env\lib\site-packages (from openapi-schema-validator<0.7.0,>=0.6.0->openapi_core<0.20,>=0.18->semantic-kernel==1.2.0) (0.1.4)
# Requirement already satisfied: lazy-object-proxy<2.0.0,>=1.7.1 in c:\users\johealy\.conda\envs\pytorch_env\lib\site-packages (from openapi-spec-validator<0.8.0,>=0.7.1->openapi_core<0.20,>=0.18->semantic-kernel==1.2.0) (1.10.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\johealy\.conda\envs\pytorch_env\lib\site-packages (from requests>=2.25->prance<24.0.0.0,>=23.6.21.0->semantic-kernel==1.2.0) (2.0.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\johealy\.conda\envs\pytorch_env\lib\site-packages (from requests>=2.25->prance<24.0.0.0,>=23.6.21.0->semantic-kernel==1.2.0) (2.1.0)
# Requirement already satisfied: ruamel.yaml.clib>=0.2.7 in c:\users\johealy\.conda\envs\pytorch_env\lib\site-packages (from ruamel.yaml>=0.17.10->prance<24.0.0.0,>=23.6.21.0->semantic-kernel==1.2.0) (0.2.8)
# Requirement already satisfied: colorama in c:\users\johealy\appdata\roaming\python\python311\site-packages (from tqdm>4->openai>=1.0->semantic-kernel==1.2.0) (0.4.6)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\johealy\.conda\envs\pytorch_env\lib\site-packages (from httpcore<0.18.0,>=0.15.0->httpx<1,>=0.23.0->openai>=1.0->semantic-kernel==1.2.0) (0.14.0)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# Initial configuration for the notebook to run properly.

# %%
# Make sure paths are correct for the imports

import os
import sys

notebook_dir = os.path.abspath("")
parent_dir = os.path.dirname(notebook_dir)
grandparent_dir = os.path.dirname(parent_dir)


sys.path.append(grandparent_dir)

# %% [markdown]
# ### Configuring the Kernel
#
# Let's get started with the necessary configuration to run Semantic Kernel. For Notebooks, we require a `.env` file with the proper settings for the model you use. Create a new file named `.env` and place it in this directory. Copy the contents of the `.env.example` file from this directory and paste it into the `.env` file that you just created.
#
# **NOTE: Please make sure to include `GLOBAL_LLM_SERVICE` set to either OpenAI, AzureOpenAI, or HuggingFace in your .env file. If this setting is not included, the Service will default to AzureOpenAI.**
#
# #### Option 1: using OpenAI
#
# Add your [OpenAI Key](https://openai.com/product/) key to your `.env` file (org Id only if you have multiple orgs):
#
# ```
# GLOBAL_LLM_SERVICE="OpenAI"
# OPENAI_API_KEY="sk-..."
# OPENAI_ORG_ID=""
# OPENAI_CHAT_MODEL_ID=""
# OPENAI_TEXT_MODEL_ID=""
# OPENAI_EMBEDDING_MODEL_ID=""
# ```
# The names should match the names used in the `.env` file, as shown above.
#
# #### Option 2: using Azure OpenAI
#
# Add your [Azure Open AI Service key](https://learn.microsoft.com/azure/cognitive-services/openai/quickstart?pivots=programming-language-studio) settings to the `.env` file in the same folder:
#
# ```
# GLOBAL_LLM_SERVICE="AzureOpenAI"
# AZURE_OPENAI_API_KEY="..."
# AZURE_OPENAI_ENDPOINT="https://..."
# AZURE_OPENAI_CHAT_DEPLOYMENT_NAME="..."
# AZURE_OPENAI_TEXT_DEPLOYMENT_NAME="..."
# AZURE_OPENAI_EMBEDDING_DEPLOYMENT_NAME="..."
# AZURE_OPENAI_API_VERSION="..."
# ```
# The names should match the names used in the `.env` file, as shown above.
#
# For more advanced configuration, please follow the steps outlined in the [setup guide](./CONFIGURING_THE_KERNEL.md).

# %% [markdown]
# We will load our settings and get the LLM service to use for the notebook.

# %%
from services import Service

from samples.service_settings import ServiceSettings

service_settings = ServiceSettings()

# Select a service to use for this notebook (available services: OpenAI, AzureOpenAI, HuggingFace)
selectedService = (
    Service.AzureOpenAI
    if service_settings.global_llm_service is None
    else Service(service_settings.global_llm_service.lower())
)
print(f"Using service type: {selectedService}")
# Out:
# Using service type: Service.AzureOpenAI

# %% [markdown]
# Let's define some imports that will be used in this example.

# %%
from semantic_kernel.contents.chat_history import ChatHistory  # noqa: F401
from semantic_kernel.functions.kernel_arguments import KernelArguments  # noqa: F401
from semantic_kernel.prompt_template.input_variable import InputVariable  # noqa: F401

# %% [markdown]
# Define your ASK. What do you want the Kernel to do?

# %%
ask = """
Tomorrow is Valentine's day. I need to come up with a few short poems.
She likes Shakespeare so write using his style. She speaks French so write it in French.
Convert the text to uppercase."""

# %% [markdown]
# ### Providing plugins to the planner
#
# The planner needs to know what plugins are available to it. Here we'll give it access to the `SummarizePlugin` and `WriterPlugin` we have defined on disk. This will include many semantic functions, of which the planner will intelligently choose a subset.
#
# You can also include native functions as well. Here we'll add the TextPlugin.

# %%
from semantic_kernel.connectors.ai.open_ai import OpenAIChatPromptExecutionSettings
from semantic_kernel.core_plugins.text_plugin import TextPlugin
from semantic_kernel.functions.kernel_function_from_prompt import KernelFunctionFromPrompt
from semantic_kernel.kernel import Kernel

kernel = Kernel()
service_id = None
if selectedService == Service.OpenAI:
    from semantic_kernel.connectors.ai.open_ai import OpenAIChatCompletion

    service_id = "default"
    kernel.add_service(
        OpenAIChatCompletion(
            service_id=service_id,
        ),
    )
elif selectedService == Service.AzureOpenAI:
    from semantic_kernel.connectors.ai.open_ai import AzureChatCompletion

    service_id = "default"
    kernel.add_service(
        AzureChatCompletion(
            service_id=service_id,
        ),
    )

plugins_directory = "../../../prompt_template_samples/"
summarize_plugin = kernel.add_plugin(plugin_name="SummarizePlugin", parent_directory=plugins_directory)
writer_plugin = kernel.add_plugin(
    plugin_name="WriterPlugin",
    parent_directory=plugins_directory,
)
text_plugin = kernel.add_plugin(plugin=TextPlugin(), plugin_name="TextPlugin")

shakespeare_func = KernelFunctionFromPrompt(
    function_name="Shakespeare",
    plugin_name="WriterPlugin",
    prompt="""
{{$input}}

Rewrite the above in the style of Shakespeare.
""",
    prompt_execution_settings=OpenAIChatPromptExecutionSettings(
        service_id=service_id,
        max_tokens=2000,
        temperature=0.8,
    ),
    description="Rewrite the input in the style of Shakespeare.",
)
kernel.add_function(plugin_name="WriterPlugin", function=shakespeare_func)

for plugin_name, plugin in kernel.plugins.items():
    for function_name, function in plugin.functions.items():
        print(f"Plugin: {plugin_name}, Function: {function_name}")
# Out:
# Plugin: SummarizePlugin, Function: MakeAbstractReadable
# Plugin: SummarizePlugin, Function: Notegen
# Plugin: SummarizePlugin, Function: Summarize
# Plugin: SummarizePlugin, Function: Topics
# Plugin: WriterPlugin, Function: Acronym
# Plugin: WriterPlugin, Function: AcronymGenerator
# Plugin: WriterPlugin, Function: AcronymReverse
# Plugin: WriterPlugin, Function: Brainstorm
# Plugin: WriterPlugin, Function: EmailGen
# Plugin: WriterPlugin, Function: EmailTo
# Plugin: WriterPlugin, Function: EnglishImprover
# Plugin: WriterPlugin, Function: NovelChapter
# Plugin: WriterPlugin, Function: NovelChapterWithNotes
# Plugin: WriterPlugin, Function: NovelOutline
# Plugin: WriterPlugin, Function: Rewrite
# Plugin: WriterPlugin, Function: ShortPoem
# Plugin: WriterPlugin, Function: StoryGen
# Plugin: WriterPlugin, Function: TellMeMore
# Plugin: WriterPlugin, Function: Translate
# Plugin: WriterPlugin, Function: TwoSentenceSummary
# Plugin: WriterPlugin, Function: Shakespeare
# Plugin: TextPlugin, Function: lowercase
# Plugin: TextPlugin, Function: trim
# Plugin: TextPlugin, Function: trim_end
# Plugin: TextPlugin, Function: trim_start
# Plugin: TextPlugin, Function: uppercase

# %% [markdown]
# # The Plan Object Model

# %% [markdown]
# To build more advanced planners, we need to introduce a proper Plan object that can contain all the necessary state and information needed for high quality plans.
#
# To see what that object model is, look at (https://github.com/microsoft/semantic-kernel/blob/main/python/semantic_kernel/planning/plan.py)

# %% [markdown]
# # Sequential Planner

# %% [markdown]
# The sequential planner is an XML-based step-by-step planner. You can see the prompt used for it here (https://github.com/microsoft/semantic-kernel/blob/main/python/semantic_kernel/planning/sequential_planner/Plugins/SequentialPlanning/skprompt.txt)

# %%
from semantic_kernel.planners import SequentialPlanner

planner = SequentialPlanner(kernel, service_id)

# %%
sequential_plan = await planner.create_plan(goal=ask)

# %% [markdown]
# To see the steps that the Sequential Planner will take, we can iterate over them and print their descriptions

# %%
print("The plan's steps are:")
for step in sequential_plan._steps:
    print(
        f"- {step.description.replace('.', '') if step.description else 'No description'} using {step.metadata.fully_qualified_name} with parameters: {step.parameters}"
    )
# Out:
# The plan's steps are:
# - Turn a scenario into a short and entertaining poem using WriterPlugin-ShortPoem with parameters: {'input': "Valentine's day love and admiration"}
# - Rewrite the input in the style of Shakespeare using WriterPlugin-Shakespeare with parameters: {'input': '$POEM'}
# - Translate the input into a language of your choice using WriterPlugin-Translate with parameters: {'input': '$SHAKESPEARE_POEM', 'language': 'French'}
# - Convert a string to uppercase using TextPlugin-uppercase with parameters: {'input': '$FRENCH_POEM'}

# %% [markdown]
# Let's ask the sequential planner to execute the plan.

# %%
result = await sequential_plan.invoke(kernel)

# %%
print(result)
# Out:
# IL Y AVAIT UNE FOIS UN GARS NOMMÉ CLYDE,
# QUI, À LA MARÉE DE LA SAINT-VALENTIN, APERÇUT,
# L'ÉTREINTE TENDRE DE L'AMOUR,
# AVEC L'ESPOIR SUR SON VISAGE,
# POURTANT, C'ÉTAIT SON FÉLIN QUI NE QUITTAIT JAMAIS SON CÔTÉ.
#
# IL A PROCURÉ DES ROSES ET DES DOUCEURS LES PLUS DIVINES,
# PARÉ DE SES VÊTEMENTS, IL BRILLAIT.
# MAIS HÉLAS, MALHEUR,
# C'ÉTAIT SON CHAT, SA VÉRITABLE ÉPOUSE,
# CAR SON CŒUR ÉTAIT ÉTERNELLEMENT SIEN.
#
# UN SONNET QU'IL ÉCRIVIT, SI DOUX ET CHER,
# AVEC DES CADEAUX DE THON ET D'HERBE À CHAT PRÈS.
# ELLE RONRONNAIT, PLEINE DE JOIE,
# COMME SA MUSE ELLE SERAIT,
# DANS LEUR LIEN, L'ESSENCE DE L'AMOUR BRILLAIT CLAIREMENT.

# %% [markdown]
# # Function Calling Stepwise Planner

# %% [markdown]
# The Function Calling Stepwise Planner is based off the paper from MRKL (Modular Reasoning, Knowledge and Language) and is similar to other papers like ReACT (Reasoning and Acting in Language Models). At the core, the stepwise planner allows for the AI to form "thoughts" and "observations" and execute actions based off those to achieve a user's goal. This continues until all required functions are complete and a final output is generated.
#
# Please note that the Function Calling Stepwise Planner uses OpenAI function calling, and so it can only use either the AzureChatCompletion or the OpenAIChatCompletion service.

# %%
from semantic_kernel.kernel import Kernel

kernel = Kernel()
service_id = None
if selectedService == Service.OpenAI:
    from semantic_kernel.connectors.ai.open_ai import OpenAIChatCompletion

    service_id = "default"
    kernel.add_service(
        OpenAIChatCompletion(
            service_id=service_id,
        ),
    )
elif selectedService == Service.AzureOpenAI:
    from semantic_kernel.connectors.ai.open_ai import AzureChatCompletion

    service_id = "default"
    kernel.add_service(
        AzureChatCompletion(
            service_id=service_id,
        ),
    )

# %% [markdown]
# Let's create a sample `EmailPlugin` that simulates handling a request to `get_email_address()` and `send_email()`.

# %%
from typing import Annotated

from semantic_kernel.functions.kernel_function_decorator import kernel_function


class EmailPlugin:
    """
    Description: EmailPlugin provides a set of functions to send emails.

    Usage:
        kernel.import_plugin_from_object(EmailPlugin(), plugin_name="email")

    Examples:
        {{email.SendEmail}} => Sends an email with the provided subject and body.
    """

    @kernel_function(name="SendEmail", description="Given an e-mail and message body, send an e-email")
    def send_email(
        self,
        subject: Annotated[str, "the subject of the email"],
        body: Annotated[str, "the body of the email"],
    ) -> Annotated[str, "the output is a string"]:
        """Sends an email with the provided subject and body."""
        return f"Email sent with subject: {subject} and body: {body}"

    @kernel_function(name="GetEmailAddress", description="Given a name, find the email address")
    def get_email_address(
        self,
        input: Annotated[str, "the name of the person"],
    ):
        email = ""
        if input == "Jane":
            email = "janedoe4321@example.com"
        elif input == "Paul":
            email = "paulsmith5678@example.com"
        elif input == "Mary":
            email = "maryjones8765@example.com"
        else:
            input = "johndoe1234@example.com"
        return email

# %% [markdown]
# We'll add this new plugin to the kernel.

# %%
kernel.add_plugin(plugin_name="EmailPlugin", plugin=EmailPlugin())
# Out:
# KernelPlugin(name='EmailPlugin', description=None, functions={'GetEmailAddress': KernelFunctionFromMethod(metadata=KernelFunctionMetadata(name='GetEmailAddress', plugin_name='EmailPlugin', description='Given a name, find the email address', parameters=[KernelParameterMetadata(name='input', description='the name of the person', default_value=None, type_='str', is_required=True, type_object=<class 'str'>, schema_data={'type': 'string', 'description': 'the name of the person'}, function_schema_include=True)], is_prompt=False, is_asynchronous=False, return_parameter=KernelParameterMetadata(name='return', description='', default_value=None, type_='Any', is_required=True, type_object=None, schema_data={'type': 'object'}, function_schema_include=True), additional_properties={}), method=<bound method EmailPlugin.get_email_address of <__main__.EmailPlugin object at 0x0000022EFCB7AD10>>, stream_method=None), 'SendEmail': KernelFunctionFromMethod(metadata=KernelFunctionMetadata(name='SendEmail', plugin_name='EmailPlugin', description='Given an e-mail and message body, send an e-email', parameters=[KernelParameterMetadata(name='subject', description='the subject of the email', default_value=None, type_='str', is_required=True, type_object=<class 'str'>, schema_data={'type': 'string', 'description': 'the subject of the email'}, function_schema_include=True), KernelParameterMetadata(name='body', description='the body of the email', default_value=None, type_='str', is_required=True, type_object=<class 'str'>, schema_data={'type': 'string', 'description': 'the body of the email'}, function_schema_include=True)], is_prompt=False, is_asynchronous=False, return_parameter=KernelParameterMetadata(name='return', description='the output is a string', default_value=None, type_='str', is_required=True, type_object=<class 'str'>, schema_data={'type': 'string', 'description': 'the output is a string'}, function_schema_include=True), additional_properties={}), method=<bound method EmailPlugin.send_email of <__main__.EmailPlugin object at 0x0000022EFCB7AD10>>, stream_method=None)})

# %% [markdown]
# Let's also add a couple more plugins.

# %%
from semantic_kernel.core_plugins.math_plugin import MathPlugin
from semantic_kernel.core_plugins.time_plugin import TimePlugin

kernel.add_plugin(plugin_name="MathPlugin", plugin=MathPlugin())
kernel.add_plugin(plugin_name="TimePlugin", plugin=TimePlugin())
# Out:
# KernelPlugin(name='TimePlugin', description=None, functions={'date': KernelFunctionFromMethod(metadata=KernelFunctionMetadata(name='date', plugin_name='TimePlugin', description='Get the current date.', parameters=[], is_prompt=False, is_asynchronous=False, return_parameter=KernelParameterMetadata(name='return', description='', default_value=None, type_='str', is_required=True, type_object=<class 'str'>, schema_data={'type': 'string'}, function_schema_include=True), additional_properties={}), method=<bound method TimePlugin.date of TimePlugin()>, stream_method=None), 'date_matching_last_day_name': KernelFunctionFromMethod(metadata=KernelFunctionMetadata(name='date_matching_last_day_name', plugin_name='TimePlugin', description='Get the date of the last day matching the supplied week day name in English.', parameters=[KernelParameterMetadata(name='day_name', description=None, default_value=None, type_='str', is_required=True, type_object=<class 'str'>, schema_data={'type': 'string'}, function_schema_include=True)], is_prompt=False, is_asynchronous=False, return_parameter=KernelParameterMetadata(name='return', description='', default_value=None, type_='str', is_required=True, type_object=<class 'str'>, schema_data={'type': 'string'}, function_schema_include=True), additional_properties={}), method=<bound method TimePlugin.date_matching_last_day_name of TimePlugin()>, stream_method=None), 'day': KernelFunctionFromMethod(metadata=KernelFunctionMetadata(name='day', plugin_name='TimePlugin', description='Get the current day', parameters=[], is_prompt=False, is_asynchronous=False, return_parameter=KernelParameterMetadata(name='return', description='', default_value=None, type_='str', is_required=True, type_object=<class 'str'>, schema_data={'type': 'string'}, function_schema_include=True), additional_properties={}), method=<bound method TimePlugin.day of TimePlugin()>, stream_method=None), 'dayOfWeek': KernelFunctionFromMethod(metadata=KernelFunctionMetadata(name='dayOfWeek', plugin_name='TimePlugin', description='Get the current day of the week', parameters=[], is_prompt=False, is_asynchronous=False, return_parameter=KernelParameterMetadata(name='return', description='', default_value=None, type_='str', is_required=True, type_object=<class 'str'>, schema_data={'type': 'string'}, function_schema_include=True), additional_properties={}), method=<bound method TimePlugin.day_of_week of TimePlugin()>, stream_method=None), 'days_ago': KernelFunctionFromMethod(metadata=KernelFunctionMetadata(name='days_ago', plugin_name='TimePlugin', description='Get the date of offset from today by a provided number of days', parameters=[KernelParameterMetadata(name='days', description=None, default_value=None, type_='str', is_required=True, type_object=<class 'str'>, schema_data={'type': 'string'}, function_schema_include=True)], is_prompt=False, is_asynchronous=False, return_parameter=KernelParameterMetadata(name='return', description='', default_value=None, type_='str', is_required=True, type_object=<class 'str'>, schema_data={'type': 'string'}, function_schema_include=True), additional_properties={}), method=<bound method TimePlugin.days_ago of TimePlugin()>, stream_method=None), 'hour': KernelFunctionFromMethod(metadata=KernelFunctionMetadata(name='hour', plugin_name='TimePlugin', description='Get the current hour', parameters=[], is_prompt=False, is_asynchronous=False, return_parameter=KernelParameterMetadata(name='return', description='', default_value=None, type_='str', is_required=True, type_object=<class 'str'>, schema_data={'type': 'string'}, function_schema_include=True), additional_properties={}), method=<bound method TimePlugin.hour of TimePlugin()>, stream_method=None), 'hourNumber': KernelFunctionFromMethod(metadata=KernelFunctionMetadata(name='hourNumber', plugin_name='TimePlugin', description='Get the current hour number', parameters=[], is_prompt=False, is_asynchronous=False, return_parameter=KernelParameterMetadata(name='return', descrip ...

# %% [markdown]
# We will define our FunctionCallingStepPlanner and the questions we want to ask.

# %%
from semantic_kernel.planners.function_calling_stepwise_planner import (
    FunctionCallingStepwisePlanner,
    FunctionCallingStepwisePlannerOptions,
)

questions = [
    "What is the current hour number, plus 5?",
    "What is 387 minus 22? Email the solution to John and Mary.",
    "Write a limerick, translate it to Spanish, and send it to Jane",
]

options = FunctionCallingStepwisePlannerOptions(
    max_iterations=10,
    max_tokens=4000,
)

planner = FunctionCallingStepwisePlanner(service_id=service_id, options=options)

# %% [markdown]
# Let's loop through the questions and invoke the planner.

# %%
for question in questions:
    result = await planner.invoke(kernel, question)
    print(f"Q: {question}\nA: {result.final_answer}\n")

    # Uncomment the following line to view the planner's process for completing the request
    print(f"Chat history: {result.chat_history}\n")
# Out:
# Q: What is the current hour number, plus 5?
# A: The current hour number plus 5 is 19.
#
# Chat history: <chat_history><message role="user"><text>Original request: What is the current hour number, plus 5?
#
# You are in the process of helping the user fulfill this request using the following plan:
# To achieve the goal of finding the current hour number plus 5, we can follow these steps:
#
# 1. Get the current hour number using the `TimePlugin-hourNumber` function.
# 2. Add 5 to the current hour number using the `MathPlugin-Add` function.
#
# Let's proceed with these steps.
#
# ### Step 1: Get the current hour number
# I will use the `TimePlugin-hourNumber` function to get the current hour number.
#
# ### Step 2: Add 5 to the current hour number
# I will use the `MathPlugin-Add` function to add 5 to the current hour number obtained in Step 1.
#
# Let's execute these steps.
#
# #### Step 1: Get the current hour number
# I will now get the current hour number.
#
# The user will ask you for help with each step.</text></message><message role="user"><text>Perform the next step of the plan if there is more work to do. When you have reached a final answer, use the UserInteraction-SendFinalAnswer function to communicate this back to the user.</text></message><message ai_model_id="jolgukwestus" finish_reason="tool_calls" role="assistant"><function_call id="call_cyU9Z3Vfv3XLZo2XSym6eDAX" name="TimePlugin-hourNumber">{}</function_call></message><message role="tool"><function_result id="call_cyU9Z3Vfv3XLZo2XSym6eDAX" name="TimePlugin-hourNumber">14</function_result></message><message role="user"><text>Perform the next step of the plan if there is more work to do. When you have reached a final answer, use the UserInteraction-SendFinalAnswer function to communicate this back to the user.</text></message><message ai_model_id="jolgukwestus" finish_reason="tool_calls" role="assistant"><function_call id="call_ly1qMxTOBL0LiwMUbqcbfrko" name="MathPlugin-Add">{"input":14,"amount":5}</function_call></message><message role="tool"><function_result id="call_ly1qMxTOBL0LiwMUbqcbfrko" name="MathPlugin-Add">19</function_result></message><message role="user"><text>Perform the next step of the plan if there is more work to do. When you have reached a final answer, use the UserInteraction-SendFinalAnswer function to communicate this back to the user.</text></message><message ai_model_id="jolgukwestus" finish_reason="tool_calls" role="assistant"><function_call id="call_cyU9Z3Vfv3XLZo2XSym6eDAX" name="UserInteraction-SendFinalAnswer">{"answer":"The current hour number plus 5 is 19."}</function_call></message></chat_history>
#
# Q: What is 387 minus 22? Email the solution to John and Mary.
# A: Subtraction result (387 - 22 = 365) has been successfully emailed to Mary at maryjones8765@example.com. However, I couldn't retrieve the email address for John.
#
# Chat history: <chat_history><message role="user"><text>Original request: What is 387 minus 22? Email the solution to John and Mary.
#
# You are in the process of helping the user fulfill this request using the following plan:
# To achieve the specified goal, we need to follow these steps:
#
# 1. Subtract 22 from 387.
# 2. Get the email addresses of John and Mary.
# 3. Send the result of the subtraction to both John and Mary.
#
# Let's break it down step-by-step:
#
# ### Step 1: Subtract 22 from 387
# We will use the `MathPlugin-Subtract` function to perform this calculation.
#
# ### Step 2: Get the email addresses of John and Mary
# We will use the `EmailPlugin-GetEmailAddress` function twice, once for John and once for Mary.
#
# ### Step 3: Send the result to both John and Mary
# We will use the `EmailPlugin-SendEmail` function twice, once for John and once for Mary.
#
# Let's start with Step 1.
#
# #### Step 1: Subtract 22 from 387
# I will use the `MathPlugin-Subtract` function to perform this calculation.
#
# The user will ask you for help with each step.</text></message><message role="user"><text>Perform the next step of the plan if there is more work to do. When you have reached a final answer, use the UserInteraction-SendFinalAnswer function to communicate this back to the user.</text></message><message ai_model_id="jolgukwestus" finish_reason="tool_calls" role="assistant"><function_call id="call_cyU9Z3Vfv3XLZo2XSym6eDAX" name="MathPlugin-Subtract">{"input":387,"amount":22}</function_call></message><message role="tool"><function_result id="call_cyU9Z3Vfv3XLZo2XSym6eDAX" name="MathPlugin-Subtract">365</function_result></message><message role="user"><text>Perform the next step of the plan if there is more work to do. When you have reached a final answer, use the UserInteraction-SendFinalAnswer function to communicate this back to the user.</text></message><message ai_model_id="jolgukwestus" finish_reason="tool_calls" role="assistant"><function_call id="call_cyU9Z3Vfv3XLZo2XSym6eDAX" name="EmailPlugin-GetEmailAddress">{"input": "John"}</function_call><function_call id="call_xRD0mzd9QnhWtGW7k2zPuzUv" name="EmailPlugin-GetEmailAddress">{"input": "Mary"}</function_call></message><message role="tool"><function_result id="call_cyU9Z3Vfv3XLZo2XSym6eDAX" name="EmailPlugin-GetEmailAddress" /></message><message role="tool"><function_result id="call_xRD0mzd9QnhWtGW7k2zPuzUv" name="EmailPlugin-GetEmailAddress">maryjones8765@example.com</function_result></message><message role="user"><text>Perform the next step of the plan if there is more work to do. When you have reached a final answer, use the UserInteraction-SendFinalAnswer function to communicate this back to the user.</text></message><message ai_model_id="jolgukwestus" finish_reason="tool_calls" role="assistant"><function_call id="call_cyU9Z3Vfv3XLZo2XSym6eDAX" name="EmailPlugin-SendEmail">{"subject":"Subtraction Result","body":"The result of 387 minus 22 is 365.","to":["maryjones8765@example.com"]}</function_call></message><message role="tool"><function_result id="call_cyU9Z3Vfv3XLZo2XSym6eDAX" name="EmailPlugin-SendEmail">Email sent with subject: Subtraction Result and body: The result of 387 minus 22 is 365.</function_result></message><message role="user"><text>Perform the next step of the plan if there is more work to do. When you have reached a final answer, use the UserInteraction-SendFinalAnswer function to communicate this back to the user.</text></message><message ai_model_id="jolgukwestus" finish_reason="tool_calls" role="assistant"><function_call id="call_ly1qMxTOBL0LiwMUbqcbfrko" name="UserInteraction-SendFinalAnswer">{"answer":"Subtraction result (387 - 22 = 365) has been successfully emailed to Mary at maryjones8765@example.com. However, I couldn't retrieve the email address for John."}</function_call></message></chat_history>
#
# Q: Write a limerick, translate it to Spanish, and send it to Jane
# A: The limerick has been successfully written, translated to Spanish, and sent to Jane at janedoe4321@example.com.
#
# Chat history: <chat_history><message role="user"><text>Original request: Write a limerick, translate it to Spanish, and send it to Jane
#
# You are in the process of helping the user fulfill this request using the following plan:
# To achieve the goal, we need to follow these steps:
#
# 1. Write a limerick.
# 2. Translate the limerick to Spanish.
# 3. Find Jane's email address.
# 4. Send the translated limerick to Jane via email.
#
# Let's start with the first step:
#
# ### Step 1: Write a limerick
# Here is a limerick:
# ```
# There once was a man from Peru,
# Who dreamed he was eating his shoe.
# He awoke with a fright,
# In the middle of the night,
# To find that his dream had come true.
# ```
#
# ### Step 2: Translate the limerick to Spanish
# Here is the translation:
# ```
# Había una vez un hombre de Perú,
# Que soñó que se comía su zapato.
# Se despertó con un susto,
# En medio de la noche,
# Para descubrir que su sueño se había hecho realidad.
# ```
#
# ### Step 3: Find Jane's email address
# We will use the function `EmailPlugin-GetEmailAddress` to find Jane's email address.
#
# ### Step 4: Send the translated limerick to Jane via email
# We will use the function `EmailPlugin-SendEmail` to send the email to Jane.
#
# Let's proceed with the plan
#
# The user will ask you for help with each step.</text></message><message role="user"><text>Perform the next step of the plan if there is more work to do. When you have reached a final answer, use the UserInteraction-SendFinalAnswer function to communicate this back to the user.</text></message><message ai_model_id="jolgukwestus" finish_reason="tool_calls" role="assistant"><function_call id="call_cyU9Z3Vfv3XLZo2XSym6eDAX" name="EmailPlugin-GetEmailAddress">{"input":"Jane"}</function_call></message><message role="tool"><function_result id="call_cyU9Z3Vfv3XLZo2XSym6eDAX" name="EmailPlugin-GetEmailAddress">janedoe4321@example.com</function_result></message><message role="user"><text>Perform the next step of the plan if there is more work to do. When you have reached a final answer, use the UserInteraction-SendFinalAnswer function to communicate this back to the user.</text></message><message ai_model_id="jolgukwestus" finish_reason="tool_calls" role="assistant"><function_call id="call_cyU9Z3Vfv3XLZo2XSym6eDAX" name="EmailPlugin-SendEmail">{"subject":"A Fun Limerick for You!","body":"Había una vez un hombre de Perú,\nQue soñó que se comía su zapato.\nSe despertó con un susto,\nEn medio de la noche,\nPara descubrir que su sueño se había hecho realidad."}</function_call></message><message role="tool"><function_result id="call_cyU9Z3Vfv3XLZo2XSym6eDAX" name="EmailPlugin-SendEmail">Email sent with subject: A Fun Limerick for You! and body: Había una vez un hombre de Perú,
# Que soñó que se comía su zapato.
# Se despertó con un susto,
# En medio de la noche,
# Para descubrir que su sueño se había hecho realidad.</function_result></message><message role="user"><text>Perform the next step of the plan if there is more work to do. When you have reached a final answer, use the UserInteraction-SendFinalAnswer function to communicate this back to the user.</text></message><message ai_model_id="jolgukwestus" finish_reason="tool_calls" role="assistant"><function_call id="call_cyU9Z3Vfv3XLZo2XSym6eDAX" name="UserInteraction-SendFinalAnswer">{"answer":"The limerick has been successfully written, translated to Spanish, and sent to Jane at janedoe4321@example.com."}</function_call></message></chat_history>
