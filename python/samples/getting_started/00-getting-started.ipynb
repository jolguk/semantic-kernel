# %% [markdown]
# # Setup
#
# Import Semantic Kernel SDK from pypi.org

# %%
# Note: if using a Poetry virtual environment, do not run this cell
# %pip install semantic-kernel==1.2.0
# Out:
# Collecting semantic-kernel==1.2.0Note: you may need to restart the kernel to use updated packages.
#
#   Downloading semantic_kernel-1.2.0-py3-none-any.whl.metadata (4.2 kB)
# Requirement already satisfied: aiohttp<4.0,>=3.8 in c:\users\johealy\.conda\envs\pytorch_env\lib\site-packages (from semantic-kernel==1.2.0) (3.9.5)
# Collecting defusedxml<0.8.0,>=0.7.1 (from semantic-kernel==1.2.0)
#   Downloading defusedxml-0.7.1-py2.py3-none-any.whl.metadata (32 kB)
# Requirement already satisfied: jinja2<4.0.0,>=3.1.3 in c:\users\johealy\appdata\roaming\python\python311\site-packages (from semantic-kernel==1.2.0) (3.1.3)
# Collecting nest-asyncio<2.0.0,>=1.6.0 (from semantic-kernel==1.2.0)
#   Downloading nest_asyncio-1.6.0-py3-none-any.whl.metadata (2.8 kB)
# Collecting numpy>=1.25 (from semantic-kernel==1.2.0)
#   Downloading numpy-2.0.0-cp311-cp311-win_amd64.whl.metadata (60 kB)
#      ---------------------------------------- 0.0/60.9 kB ? eta -:--:--
#      ---------------------------------------- 60.9/60.9 kB 1.6 MB/s eta 0:00:00
# Collecting openai>=1.0 (from semantic-kernel==1.2.0)
#   Downloading openai-1.35.13-py3-none-any.whl.metadata (21 kB)
# Collecting openapi_core<0.20,>=0.18 (from semantic-kernel==1.2.0)
#   Downloading openapi_core-0.19.2-py3-none-any.whl.metadata (6.4 kB)
# Collecting prance<24.0.0.0,>=23.6.21.0 (from semantic-kernel==1.2.0)
#   Downloading prance-23.6.21.0-py3-none-any.whl.metadata (13 kB)
# Collecting pybars4<0.10.0,>=0.9.13 (from semantic-kernel==1.2.0)
#   Downloading pybars4-0.9.13.tar.gz (29 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting pydantic<3,>=2 (from semantic-kernel==1.2.0)
#   Downloading pydantic-2.8.2-py3-none-any.whl.metadata (125 kB)
#      ---------------------------------------- 0.0/125.2 kB ? eta -:--:--
#      -------------------------------------- 125.2/125.2 kB 3.6 MB/s eta 0:00:00
# Collecting pydantic-settings<3,>=2 (from semantic-kernel==1.2.0)
#   Downloading pydantic_settings-2.3.4-py3-none-any.whl.metadata (3.3 kB)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\johealy\.conda\envs\pytorch_env\lib\site-packages (from aiohttp<4.0,>=3.8->semantic-kernel==1.2.0) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\johealy\.conda\envs\pytorch_env\lib\site-packages (from aiohttp<4.0,>=3.8->semantic-kernel==1.2.0) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\johealy\.conda\envs\pytorch_env\lib\site-packages (from aiohttp<4.0,>=3.8->semantic-kernel==1.2.0) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\johealy\.conda\envs\pytorch_env\lib\site-packages (from aiohttp<4.0,>=3.8->semantic-kernel==1.2.0) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in c:\users\johealy\.conda\envs\pytorch_env\lib\site-packages (from aiohttp<4.0,>=3.8->semantic-kernel==1.2.0) (1.9.4)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\johealy\appdata\roaming\python\python311\site-packages (from jinja2<4.0.0,>=3.1.3->semantic-kernel==1.2.0) (2.1.5)
# Requirement already satisfied: anyio<5,>=3.5.0 in c:\users\johealy\.conda\envs\pytorch_env\lib\site-packages (from openai>=1.0->semantic-kernel==1.2.0) (4.3.0)
# Collecting distro<2,>=1.7.0 (from openai>=1.0->semantic-kernel==1.2.0)
#   Using cached distro-1.9.0-py3-none-any.whl.metadata (6.8 kB)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\johealy\.conda\envs\pytorch_env\lib\site-packages (from openai>=1.0->semantic-kernel==1.2.0) (0.24.1)
# Requirement already satisfied: sniffio in c:\users\johealy\.conda\envs\pytorch_env\lib\site-packages (from openai>=1.0->semantic-kernel==1.2.0) (1.3.1)
# Requirement already satisfied: tqdm>4 in c:\users\johealy\.conda\envs\pytorch_env\lib\site-packages (from openai>=1.0->semantic-kernel==1.2.0) (4.66.4)
# Requirement already satisfied: typing-extensions<5,>=4.7 in c:\users\johealy\.conda\envs\pytorch_env\lib\site-packages (from openai>=1.0->semantic-kernel==1.2.0) (4.12.2)
# Collecting isodate (from openapi_core<0.20,>=0.18->semantic-kernel==1.2.0)
#   Using cached isodate-0.6.1-py2.py3-none-any.whl.metadata (9.6 kB)
# Collecting jsonschema<5.0.0,>=4.18.0 (from openapi_core<0.20,>=0.18->semantic-kernel==1.2.0)
#   Downloading jsonschema-4.23.0-py3-none-any.whl.metadata (7.9 kB)
# Collecting jsonschema-path<0.4.0,>=0.3.1 (from openapi_core<0.20,>=0.18->semantic-kernel==1.2.0)
#   Downloading jsonschema_path-0.3.3-py3-none-any.whl.metadata (4.3 kB)
# Collecting more-itertools (from openapi_core<0.20,>=0.18->semantic-kernel==1.2.0)
#   Downloading more_itertools-10.3.0-py3-none-any.whl.metadata (36 kB)
# Collecting openapi-schema-validator<0.7.0,>=0.6.0 (from openapi_core<0.20,>=0.18->semantic-kernel==1.2.0)
#   Downloading openapi_schema_validator-0.6.2-py3-none-any.whl.metadata (5.3 kB)
# Collecting openapi-spec-validator<0.8.0,>=0.7.1 (from openapi_core<0.20,>=0.18->semantic-kernel==1.2.0)
#   Downloading openapi_spec_validator-0.7.1-py3-none-any.whl.metadata (5.7 kB)
# Collecting parse (from openapi_core<0.20,>=0.18->semantic-kernel==1.2.0)
#   Downloading parse-1.20.2-py2.py3-none-any.whl.metadata (22 kB)
# Collecting werkzeug (from openapi_core<0.20,>=0.18->semantic-kernel==1.2.0)
#   Downloading werkzeug-3.0.3-py3-none-any.whl.metadata (3.7 kB)
# Collecting chardet>=3.0 (from prance<24.0.0.0,>=23.6.21.0->semantic-kernel==1.2.0)
#   Using cached chardet-5.2.0-py3-none-any.whl.metadata (3.4 kB)
# Collecting ruamel.yaml>=0.17.10 (from prance<24.0.0.0,>=23.6.21.0->semantic-kernel==1.2.0)
#   Using cached ruamel.yaml-0.18.6-py3-none-any.whl.metadata (23 kB)
# Requirement already satisfied: requests>=2.25 in c:\users\johealy\.conda\envs\pytorch_env\lib\site-packages (from prance<24.0.0.0,>=23.6.21.0->semantic-kernel==1.2.0) (2.31.0)
# Requirement already satisfied: six~=1.15 in c:\users\johealy\.conda\envs\pytorch_env\lib\site-packages (from prance<24.0.0.0,>=23.6.21.0->semantic-kernel==1.2.0) (1.16.0)
# Requirement already satisfied: packaging>=21.3 in c:\users\johealy\appdata\roaming\python\python311\site-packages (from prance<24.0.0.0,>=23.6.21.0->semantic-kernel==1.2.0) (23.2)
# Collecting PyMeta3>=0.5.1 (from pybars4<0.10.0,>=0.9.13->semantic-kernel==1.2.0)
#   Downloading PyMeta3-0.5.1.tar.gz (29 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting annotated-types>=0.4.0 (from pydantic<3,>=2->semantic-kernel==1.2.0)
#   Downloading annotated_types-0.7.0-py3-none-any.whl.metadata (15 kB)
# Collecting pydantic-core==2.20.1 (from pydantic<3,>=2->semantic-kernel==1.2.0)
#   Downloading pydantic_core-2.20.1-cp311-none-win_amd64.whl.metadata (6.7 kB)
# Requirement already satisfied: python-dotenv>=0.21.0 in c:\users\johealy\.conda\envs\pytorch_env\lib\site-packages (from pydantic-settings<3,>=2->semantic-kernel==1.2.0) (1.0.1)
# Requirement already satisfied: idna>=2.8 in c:\users\johealy\.conda\envs\pytorch_env\lib\site-packages (from anyio<5,>=3.5.0->openai>=1.0->semantic-kernel==1.2.0) (3.7)
# Requirement already satisfied: certifi in c:\users\johealy\.conda\envs\pytorch_env\lib\site-packages (from httpx<1,>=0.23.0->openai>=1.0->semantic-kernel==1.2.0) (2024.2.2)
# Requirement already satisfied: httpcore<0.18.0,>=0.15.0 in c:\users\johealy\.conda\envs\pytorch_env\lib\site-packages (from httpx<1,>=0.23.0->openai>=1.0->semantic-kernel==1.2.0) (0.17.3)
# Collecting jsonschema-specifications>=2023.03.6 (from jsonschema<5.0.0,>=4.18.0->openapi_core<0.20,>=0.18->semantic-kernel==1.2.0)
#   Using cached jsonschema_specifications-2023.12.1-py3-none-any.whl.metadata (3.0 kB)
# Collecting referencing>=0.28.4 (from jsonschema<5.0.0,>=4.18.0->openapi_core<0.20,>=0.18->semantic-kernel==1.2.0)
#   Downloading referencing-0.35.1-py3-none-any.whl.metadata (2.8 kB)
# Collecting rpds-py>=0.7.1 (from jsonschema<5.0.0,>=4.18.0->openapi_core<0.20,>=0.18->semantic-kernel==1.2.0)
#   Downloading rpds_py-0.19.0-cp311-none-win_amd64.whl.metadata (4.2 kB)
# Requirement already satisfied: PyYAML>=5.1 in c:\users\johealy\.conda\envs\pytorch_env\lib\site-packages (from jsonschema-path<0.4.0,>=0.3.1->openapi_core<0.20,>=0.18->semantic-kernel==1.2.0) (6.0.1)
# Collecting pathable<0.5.0,>=0.4.1 (from jsonschema-path<0.4.0,>=0.3.1->openapi_core<0.20,>=0.18->semantic-kernel==1.2.0)
#   Downloading pathable-0.4.3-py3-none-any.whl.metadata (1.9 kB)
# Collecting rfc3339-validator (from openapi-schema-validator<0.7.0,>=0.6.0->openapi_core<0.20,>=0.18->semantic-kernel==1.2.0)
#   Downloading rfc3339_validator-0.1.4-py2.py3-none-any.whl.metadata (1.5 kB)
# Collecting lazy-object-proxy<2.0.0,>=1.7.1 (from openapi-spec-validator<0.8.0,>=0.7.1->openapi_core<0.20,>=0.18->semantic-kernel==1.2.0)
#   Downloading lazy_object_proxy-1.10.0-cp311-cp311-win_amd64.whl.metadata (8.1 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\johealy\.conda\envs\pytorch_env\lib\site-packages (from requests>=2.25->prance<24.0.0.0,>=23.6.21.0->semantic-kernel==1.2.0) (2.0.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\johealy\.conda\envs\pytorch_env\lib\site-packages (from requests>=2.25->prance<24.0.0.0,>=23.6.21.0->semantic-kernel==1.2.0) (2.1.0)
# Collecting ruamel.yaml.clib>=0.2.7 (from ruamel.yaml>=0.17.10->prance<24.0.0.0,>=23.6.21.0->semantic-kernel==1.2.0)
#   Using cached ruamel.yaml.clib-0.2.8-cp311-cp311-win_amd64.whl.metadata (2.3 kB)
# Requirement already satisfied: colorama in c:\users\johealy\appdata\roaming\python\python311\site-packages (from tqdm>4->openai>=1.0->semantic-kernel==1.2.0) (0.4.6)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\johealy\.conda\envs\pytorch_env\lib\site-packages (from httpcore<0.18.0,>=0.15.0->httpx<1,>=0.23.0->openai>=1.0->semantic-kernel==1.2.0) (0.14.0)
# Downloading semantic_kernel-1.2.0-py3-none-any.whl (324 kB)
#    ---------------------------------------- 0.0/324.4 kB ? eta -:--:--
#    --------------------------------------  317.4/324.4 kB 19.2 MB/s eta 0:00:01
#    ---------------------------------------- 324.4/324.4 kB 5.0 MB/s eta 0:00:00
# Downloading defusedxml-0.7.1-py2.py3-none-any.whl (25 kB)
# Downloading nest_asyncio-1.6.0-py3-none-any.whl (5.2 kB)
# Downloading numpy-2.0.0-cp311-cp311-win_amd64.whl (16.5 MB)
#    ---------------------------------------- 0.0/16.5 MB ? eta -:--:--
#     --------------------------------------- 0.2/16.5 MB 7.3 MB/s eta 0:00:03
#    - -------------------------------------- 0.4/16.5 MB 4.5 MB/s eta 0:00:04
#    - -------------------------------------- 0.6/16.5 MB 5.0 MB/s eta 0:00:04
#    - -------------------------------------- 0.7/16.5 MB 4.5 MB/s eta 0:00:04
#    - -------------------------------------- 0.7/16.5 MB 4.5 MB/s eta 0:00:04
#    -- ------------------------------------- 0.9/16.5 MB 3.5 MB/s eta 0:00:05
#    -- ------------------------------------- 1.1/16.5 MB 3.6 MB/s eta 0:00:05
#    --- ------------------------------------ 1.3/16.5 MB 3.6 MB/s eta 0:00:05
#    --- ------------------------------------ 1.5/16.5 MB 3.6 MB/s eta 0:00:05
#    ---- ----------------------------------- 1.7/16.5 MB 3.6 MB/s eta 0:00:05
#    ---- ----------------------------------- 1.9/16.5 MB 3.7 MB/s eta 0:00:04
#    ----- ---------------------------------- 2.1/16.5 MB 3.8 MB/s eta 0:00:04
#    ----- ---------------------------------- 2.2/16.5 MB 3.6 MB/s eta 0:00:04
#    ----- ---------------------------------- 2.4/16.5 MB 3.6 MB/s eta 0:00:04
#    ------ --------------------------------- 2.6/16.5 MB 3.6 MB/s eta 0:00:04
#    ------ --------------------------------- 2.7/16.5 MB 3.6 MB/s eta 0:00:04
#    ------- -------------------------------- 2.9/16.5 MB 3.6 MB/s eta 0:00:04
#    ------- -------------------------------- 3.1/16.5 MB 3.7 MB/s eta 0:00:04
#    ------- -------------------------------- 3.3/16.5 MB 3.7 MB/s eta 0:00:04
#    -------- ------------------------------- 3.4/16.5 MB 3.7 MB/s eta 0:00:04
#    -------- ------------------------------- 3.5/16.5 MB 3.6 MB/s eta 0:00:04
#    -------- ------------------------------- 3.7/16.5 MB 3.6 MB/s eta 0:00:04
#    --------- ------------------------------ 3.9/16.5 MB 3.6 MB/s eta 0:00:04
#    --------- ------------------------------ 4.1/16.5 MB 3.6 MB/s eta 0:00:04
#    ---------- ----------------------------- 4.2/16.5 MB 3.6 MB/s eta 0:00:04
#    ---------- ----------------------------- 4.4/16.5 MB 3.6 MB/s eta 0:00:04
#    ----------- ---------------------------- 4.6/16.5 MB 3.6 MB/s eta 0:00:04
#    ----------- ---------------------------- 4.7/16.5 MB 3.6 MB/s eta 0:00:04
#    ----------- ---------------------------- 4.9/16.5 MB 3.6 MB/s eta 0:00:04
#    ------------ --------------------------- 5.1/16.5 MB 3.6 MB/s eta 0:00:04
#    ------------ --------------------------- 5.2/16.5 MB 3.5 MB/s eta 0:00:04
#    ------------ --------------------------- 5.2/16.5 MB 3.5 MB/s eta 0:00:04
#    ------------ --------------------------- 5.2/16.5 MB 3.5 MB/s eta 0:00:04
#    -------------- ------------------------- 5.8/16.5 MB 3.5 MB/s eta 0:00:04
#    -------------- ------------------------- 6.1/16.5 MB 3.6 MB/s eta 0:00:03
#    --------------- ------------------------ 6.3/16.5 MB 3.6 MB/s eta 0:00:03
#    --------------- ------------------------ 6.4/16.5 MB 3.6 MB/s eta 0:00:03
#    ---------------- ----------------------- 6.8/16.5 MB 3.7 MB/s eta 0:00:03
#    ----------------- ---------------------- 7.0/16.5 MB 3.7 MB/s eta 0:00:03
#    ----------------- ---------------------- 7.2/16.5 MB 3.7 MB/s eta 0:00:03
#    ------------------ --------------------- 7.5/16.5 MB 3.8 MB/s eta 0:00:03
#    ------------------ --------------------- 7.7/16.5 MB 3.8 MB/s eta 0:00:03
#    ------------------- -------------------- 7.9/16.5 MB 3.8 MB/s eta 0:00:03
#    ------------------- -------------------- 8.1/16.5 MB 3.8 MB/s eta 0:00:03
#    -------------------- ------------------- 8.3/16.5 MB 3.8 MB/s eta 0:00:03
#    -------------------- ------------------- 8.5/16.5 MB 3.8 MB/s eta 0:00:03
#    --------------------- ------------------ 8.7/16.5 MB 3.8 MB/s eta 0:00:03
#    --------------------- ------------------ 8.8/16.5 MB 3.8 MB/s eta 0:00:03
#    --------------------- ------------------ 9.0/16.5 MB 3.8 MB/s eta 0:00:02
#    ---------------------- ----------------- 9.2/16.5 MB 3.8 MB/s eta 0:00:02
#    ---------------------- ----------------- 9.4/16.5 MB 3.8 MB/s eta 0:00:02
#    ----------------------- ---------------- 9.6/16.5 MB 3.8 MB/s eta 0:00:02
#    ----------------------- ---------------- 9.8/16.5 MB 3.8 MB/s eta 0:00:02
#    ------------------------ --------------- 10.0/16.5 MB 3.8 MB/s eta 0:00:02
#    ------------------------ --------------- 10.2/16.5 MB 3.8 MB/s eta 0:00:02
#    ------------------------- -------------- 10.5/16.5 MB 3.8 MB/s eta 0:00:02
#    ------------------------- -------------- 10.7/16.5 MB 3.8 MB/s eta 0:00:02
#    -------------------------- ------------- 10.9/16.5 MB 3.9 MB/s eta 0:00:02
#    -------------------------- ------------- 11.1/16.5 MB 3.9 MB/s eta 0:00:02
#    --------------------------- ------------ 11.4/16.5 MB 4.0 MB/s eta 0:00:02
#    --------------------------- ------------ 11.5/16.5 MB 4.0 MB/s eta 0:00:02
#    ---------------------------- ----------- 11.8/16.5 MB 4.0 MB/s eta 0:00:02
#    ---------------------------- ----------- 12.0/16.5 MB 4.0 MB/s eta 0:00:02
#    ----------------------------- ---------- 12.1/16.5 MB 4.0 MB/s eta 0:00:02
#    ----------------------------- ---------- 12.3/16.5 MB 4.0 MB/s eta 0:00:02
#    ------------------------------ --------- 12.6/16.5 MB 4.0 MB/s eta 0:00:01
#    ------------------------------ --------- 12.7/16.5 MB 4.0 MB/s eta 0:00:01
#    ------------------------------- -------- 13.0/16.5 MB 4.0 MB/s eta 0:00:01
#    -------------------------------- ------- 13.2/16.5 MB 4.0 MB/s eta 0:00:01
#    -------------------------------- ------- 13.4/16.5 MB 4.0 MB/s eta 0:00:01
#    -------------------------------- ------- 13.6/16.5 MB 4.0 MB/s eta 0:00:01
#    --------------------------------- ------ 13.8/16.5 MB 4.1 MB/s eta 0:00:01
#    --------------------------------- ------ 14.0/16.5 MB 4.1 MB/s eta 0:00:01
#    ---------------------------------- ----- 14.2/16.5 MB 4.2 MB/s eta 0:00:01
#    ---------------------------------- ----- 14.4/16.5 MB 4.2 MB/s eta 0:00:01
#    ----------------------------------- ---- 14.6/16.5 MB 4.2 MB/s eta 0:00:01
#    ----------------------------------- ---- 14.8/16.5 MB 4.1 MB/s eta 0:00:01
#    ------------------------------------ --- 15.1/16.5 MB 4.2 MB/s eta 0:00:01
#    ------------------------------------- -- 15.4/16.5 MB 4.3 MB/s eta 0:00:01
#    ------------------------------------- -- 15.6/16.5 MB 4.5 MB/s eta 0:00:01
#    -------------------------------------- - 15.8/16.5 MB 4.4 MB/s eta 0:00:01
#    -------------------------------------- - 16.0/16.5 MB 4.3 MB/s eta 0:00:01
#    ---------------------------------------  16.2/16.5 MB 4.3 MB/s eta 0:00:01
#    ---------------------------------------  16.3/16.5 MB 4.3 MB/s eta 0:00:01
#    ---------------------------------------  16.5/16.5 MB 4.2 MB/s eta 0:00:01
#    ---------------------------------------  16.5/16.5 MB 4.3 MB/s eta 0:00:01
#    ---------------------------------------  16.5/16.5 MB 4.3 MB/s eta 0:00:01
#    ---------------------------------------  16.5/16.5 MB 4.3 MB/s eta 0:00:01
#    ---------------------------------------- 16.5/16.5 MB 4.0 MB/s eta 0:00:00
# Downloading openai-1.35.13-py3-none-any.whl (328 kB)
#    ---------------------------------------- 0.0/328.5 kB ? eta -:--:--
#    --------------------- ------------------ 174.1/328.5 kB 5.1 MB/s eta 0:00:01
#    ---------------------------------------  327.7/328.5 kB 5.0 MB/s eta 0:00:01
#    ---------------------------------------- 328.5/328.5 kB 3.4 MB/s eta 0:00:00
# Downloading openapi_core-0.19.2-py3-none-any.whl (103 kB)
#    ---------------------------------------- 0.0/103.5 kB ? eta -:--:--
#    ---------------------------------------- 103.5/103.5 kB 2.9 MB/s eta 0:00:00
# Downloading prance-23.6.21.0-py3-none-any.whl (36 kB)
# Downloading pydantic-2.8.2-py3-none-any.whl (423 kB)
#    ---------------------------------------- 0.0/423.9 kB ? eta -:--:--
#    --------------------- ------------------ 225.3/423.9 kB 4.6 MB/s eta 0:00:01
#    ---------------------------------------  419.8/423.9 kB 5.2 MB/s eta 0:00:01
#    ---------------------------------------- 423.9/423.9 kB 3.8 MB/s eta 0:00:00
# Downloading pydantic_core-2.20.1-cp311-none-win_amd64.whl (1.9 MB)
#    ---------------------------------------- 0.0/1.9 MB ? eta -:--:--
#    --- ------------------------------------ 0.2/1.9 MB 5.3 MB/s eta 0:00:01
#    ------- -------------------------------- 0.4/1.9 MB 4.6 MB/s eta 0:00:01
#    ----------- ---------------------------- 0.6/1.9 MB 4.3 MB/s eta 0:00:01
#    ----------------- ---------------------- 0.8/1.9 MB 4.1 MB/s eta 0:00:01
#    --------------------- ------------------ 1.0/1.9 MB 4.0 MB/s eta 0:00:01
#    --------------------------- ------------ 1.3/1.9 MB 4.1 MB/s eta 0:00:01
#    ----------------------------- ---------- 1.4/1.9 MB 4.1 MB/s eta 0:00:01
#    ------------------------------------- -- 1.8/1.9 MB 4.3 MB/s eta 0:00:01
#    ---------------------------------------  1.9/1.9 MB 4.2 MB/s eta 0:00:01
#    ---------------------------------------- 1.9/1.9 MB 3.9 MB/s eta 0:00:00
# Downloading pydantic_settings-2.3.4-py3-none-any.whl (22 kB)
# Downloading annotated_types-0.7.0-py3-none-any.whl (13 kB)
# Using cached chardet-5.2.0-py3-none-any.whl (199 kB)
# Using cached distro-1.9.0-py3-none-any.whl (20 kB)
# Downloading jsonschema-4.23.0-py3-none-any.whl (88 kB)
#    ---------------------------------------- 0.0/88.5 kB ? eta -:--:--
#    ---------------------------------------- 88.5/88.5 kB 2.5 MB/s eta 0:00:00
# Downloading jsonschema_path-0.3.3-py3-none-any.whl (14 kB)
# Downloading openapi_schema_validator-0.6.2-py3-none-any.whl (8.8 kB)
# Downloading openapi_spec_validator-0.7.1-py3-none-any.whl (38 kB)
# Using cached ruamel.yaml-0.18.6-py3-none-any.whl (117 kB)
# Using cached isodate-0.6.1-py2.py3-none-any.whl (41 kB)
# Downloading more_itertools-10.3.0-py3-none-any.whl (59 kB)
#    ---------------------------------------- 0.0/59.2 kB ? eta -:--:--
#    ---------------------------------------- 59.2/59.2 kB 3.1 MB/s eta 0:00:00
# Downloading parse-1.20.2-py2.py3-none-any.whl (20 kB)
# Downloading werkzeug-3.0.3-py3-none-any.whl (227 kB)
#    ---------------------------------------- 0.0/227.3 kB ? eta -:--:--
#    ---------------------------------------  225.3/227.3 kB 6.9 MB/s eta 0:00:01
#    ---------------------------------------- 227.3/227.3 kB 4.6 MB/s eta 0:00:00
# Using cached jsonschema_specifications-2023.12.1-py3-none-any.whl (18 kB)
# Downloading lazy_object_proxy-1.10.0-cp311-cp311-win_amd64.whl (27 kB)
# Downloading pathable-0.4.3-py3-none-any.whl (9.6 kB)
# Downloading referencing-0.35.1-py3-none-any.whl (26 kB)
# Downloading rpds_py-0.19.0-cp311-none-win_amd64.whl (211 kB)
#    ---------------------------------------- 0.0/211.5 kB ? eta -:--:--
#    ---------------------------------------- 211.5/211.5 kB 4.3 MB/s eta 0:00:00
# Using cached ruamel.yaml.clib-0.2.8-cp311-cp311-win_amd64.whl (118 kB)
# Downloading rfc3339_validator-0.1.4-py2.py3-none-any.whl (3.5 kB)
# Building wheels for collected packages: pybars4, PyMeta3
#   Building wheel for pybars4 (setup.py): started
#   Building wheel for pybars4 (setup.py): finished with status 'done'
#   Created wheel for pybars4: filename=pybars4-0.9.13-py3-none-any.whl size=14350 sha256=3bfdd526dc72b9a590a7715512a4e6bef794e849454a160b4fbb10e1af6937d7
#   Stored in directory: c:\users\johealy\appdata\local\pip\cache\wheels\9d\91\9b\2590c830475e613f1996fe9ce7876d5d31c346fb73a48838ad
#   Building wheel for PyMeta3 (setup.py): started
#   Building wheel for PyMeta3 (setup.py): finished with status 'done'
#   Created wheel for PyMeta3: filename=PyMeta3-0.5.1-py3-none-any.whl size=16488 sha256=63b01a0c744f589caf5a3d492b02c06348a6d405dcc204c1440a37dbdf15a500
#   Stored in directory: c:\users\johealy\appdata\local\pip\cache\wheels\67\18\5a\5a3a19ff18c8118a8dd11204dcde08349c2bbbdd77ac45b6a7
# Successfully built pybars4 PyMeta3
# Installing collected packages: PyMeta3, parse, werkzeug, ruamel.yaml.clib, rpds-py, rfc3339-validator, pydantic-core, pybars4, pathable, numpy, nest-asyncio, more-itertools, lazy-object-proxy, isodate, distro, defusedxml, chardet, annotated-types, ruamel.yaml, referencing, pydantic, pydantic-settings, prance, jsonschema-specifications, jsonschema-path, openai, jsonschema, openapi-schema-validator, openapi-spec-validator, openapi_core, semantic-kernel
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.24.3
#     Uninstalling numpy-1.24.3:
#       Successfully uninstalled numpy-1.24.3
#   Attempting uninstall: nest-asyncio
#     Found existing installation: nest-asyncio 1.5.8
#     Uninstalling nest-asyncio-1.5.8:
#       Successfully uninstalled nest-asyncio-1.5.8
#   Attempting uninstall: pydantic
#     Found existing installation: pydantic 1.10.15
#     Uninstalling pydantic-1.10.15:
#       Successfully uninstalled pydantic-1.10.15
# Successfully installed PyMeta3-0.5.1 annotated-types-0.7.0 chardet-5.2.0 defusedxml-0.7.1 distro-1.9.0 isodate-0.6.1 jsonschema-4.23.0 jsonschema-path-0.3.3 jsonschema-specifications-2023.12.1 lazy-object-proxy-1.10.0 more-itertools-10.3.0 nest-asyncio-1.6.0 numpy-2.0.0 openai-1.35.13 openapi-schema-validator-0.6.2 openapi-spec-validator-0.7.1 openapi_core-0.19.2 parse-1.20.2 pathable-0.4.3 prance-23.6.21.0 pybars4-0.9.13 pydantic-2.8.2 pydantic-core-2.20.1 pydantic-settings-2.3.4 referencing-0.35.1 rfc3339-validator-0.1.4 rpds-py-0.19.0 ruamel.yaml-0.18.6 ruamel.yaml.clib-0.2.8 semantic-kernel-1.2.0 werkzeug-3.0.3
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# fal-serverless 0.6.41 requires pydantic<2.0, but you have pydantic 2.8.2 which is incompatible.
# fal-serverless 0.6.41 requires typing-extensions==4.5, but you have typing-extensions 4.12.2 which is incompatible.

# %% [markdown]
# Initial configuration for the notebook to run properly.

# %%
# Make sure paths are correct for the imports

import os
import sys

notebook_dir = os.path.abspath("")
parent_dir = os.path.dirname(notebook_dir)
grandparent_dir = os.path.dirname(parent_dir)


sys.path.append(grandparent_dir)

# %% [markdown]
# ### Configuring the Kernel
#
# Let's get started with the necessary configuration to run Semantic Kernel. For Notebooks, we require a `.env` file with the proper settings for the model you use. Create a new file named `.env` and place it in this directory. Copy the contents of the `.env.example` file from this directory and paste it into the `.env` file that you just created.
#
# **NOTE: Please make sure to include `GLOBAL_LLM_SERVICE` set to either OpenAI, AzureOpenAI, or HuggingFace in your .env file. If this setting is not included, the Service will default to AzureOpenAI.**
#
# #### Option 1: using OpenAI
#
# Add your [OpenAI Key](https://openai.com/product/) key to your `.env` file (org Id only if you have multiple orgs):
#
# ```
# GLOBAL_LLM_SERVICE="OpenAI"
# OPENAI_API_KEY="sk-..."
# OPENAI_ORG_ID=""
# OPENAI_CHAT_MODEL_ID=""
# OPENAI_TEXT_MODEL_ID=""
# OPENAI_EMBEDDING_MODEL_ID=""
# ```
# The names should match the names used in the `.env` file, as shown above.
#
# #### Option 2: using Azure OpenAI
#
# Add your [Azure Open AI Service key](https://learn.microsoft.com/azure/cognitive-services/openai/quickstart?pivots=programming-language-studio) settings to the `.env` file in the same folder:
#
# ```
# GLOBAL_LLM_SERVICE="AzureOpenAI"
# AZURE_OPENAI_API_KEY="..."
# AZURE_OPENAI_ENDPOINT="https://..."
# AZURE_OPENAI_CHAT_DEPLOYMENT_NAME="..."
# AZURE_OPENAI_TEXT_DEPLOYMENT_NAME="..."
# AZURE_OPENAI_EMBEDDING_DEPLOYMENT_NAME="..."
# AZURE_OPENAI_API_VERSION="..."
# ```
# The names should match the names used in the `.env` file, as shown above.
#
# For more advanced configuration, please follow the steps outlined in the [setup guide](./CONFIGURING_THE_KERNEL.md).

# %% [markdown]
# Let's define our kernel for this example.

# %%
from semantic_kernel import Kernel

kernel = Kernel()

# %% [markdown]
# We will load our settings and get the LLM service to use for the notebook.

# %%
from services import Service

from samples.service_settings import ServiceSettings

service_settings = ServiceSettings()

# Select a service to use for this notebook (available services: OpenAI, AzureOpenAI, HuggingFace)
selectedService = (
    Service.AzureOpenAI
    if service_settings.global_llm_service is None
    else Service(service_settings.global_llm_service.lower())
)
print(f"Using service type: {selectedService}")
# Out:
# Using service type: Service.AzureOpenAI

# %% [markdown]
# We now configure our Chat Completion service on the kernel.

# %%
# Remove all services so that this cell can be re-run without restarting the kernel
kernel.remove_all_services()

service_id = None
if selectedService == Service.OpenAI:
    from semantic_kernel.connectors.ai.open_ai import OpenAIChatCompletion

    service_id = "default"
    kernel.add_service(
        OpenAIChatCompletion(
            service_id=service_id,
        ),
    )
elif selectedService == Service.AzureOpenAI:
    from semantic_kernel.connectors.ai.open_ai import AzureChatCompletion

    service_id = "default"
    kernel.add_service(
        AzureChatCompletion(
            service_id=service_id,
        ),
    )

# %% [markdown]
# # Run a Semantic Function
#
# **Step 3**: Load a Plugin and run a semantic function:

# %%
plugin = kernel.add_plugin(parent_directory="../../../prompt_template_samples/", plugin_name="FunPlugin")

# %%
from semantic_kernel.functions import KernelArguments

joke_function = plugin["Joke"]

joke = await kernel.invoke(
    joke_function,
    KernelArguments(input="time travel to dinosaur age", style="super silly"),
)
print(joke)
# Out:
# Why did the time traveler bring a ladder to the dinosaur age?
#
# Because he heard the Brachiosaurus had the best "high" fives!
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
