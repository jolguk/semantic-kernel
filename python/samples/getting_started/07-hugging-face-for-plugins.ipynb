# %% [markdown]
# # Using Hugging Face With Plugins
#
# In this notebook, we demonstrate using Hugging Face models for Plugins using both SemanticMemory and text completions.
#
# SK supports downloading models from the Hugging Face that can perform the following tasks: text-generation, text2text-generation, summarization, and sentence-similarity. You can search for models by task at https://huggingface.co/models.

# %%
# Note: if using a Poetry virtual environment, do not run this cell
# %pip install semantic-kernel[hugging_face]==1.2.0
# Out:
# Requirement already satisfied: semantic-kernel==1.2.0 in c:\users\johealy\.conda\envs\pytorch_env\lib\site-packages (from semantic-kernel[hugging_face]==1.2.0) (1.2.0)
# Requirement already satisfied: aiohttp<4.0,>=3.8 in c:\users\johealy\.conda\envs\pytorch_env\lib\site-packages (from semantic-kernel==1.2.0->semantic-kernel[hugging_face]==1.2.0) (3.9.5)
# Requirement already satisfied: defusedxml<0.8.0,>=0.7.1 in c:\users\johealy\.conda\envs\pytorch_env\lib\site-packages (from semantic-kernel==1.2.0->semantic-kernel[hugging_face]==1.2.0) (0.7.1)
# Requirement already satisfied: jinja2<4.0.0,>=3.1.3 in c:\users\johealy\appdata\roaming\python\python311\site-packages (from semantic-kernel==1.2.0->semantic-kernel[hugging_face]==1.2.0) (3.1.3)
# Requirement already satisfied: nest-asyncio<2.0.0,>=1.6.0 in c:\users\johealy\.conda\envs\pytorch_env\lib\site-packages (from semantic-kernel==1.2.0->semantic-kernel[hugging_face]==1.2.0) (1.6.0)
# Requirement already satisfied: numpy>=1.25 in c:\users\johealy\.conda\envs\pytorch_env\lib\site-packages (from semantic-kernel==1.2.0->semantic-kernel[hugging_face]==1.2.0) (2.0.0)
# Requirement already satisfied: openai>=1.0 in c:\users\johealy\.conda\envs\pytorch_env\lib\site-packages (from semantic-kernel==1.2.0->semantic-kernel[hugging_face]==1.2.0) (1.35.13)
# Requirement already satisfied: openapi_core<0.20,>=0.18 in c:\users\johealy\.conda\envs\pytorch_env\lib\site-packages (from semantic-kernel==1.2.0->semantic-kernel[hugging_face]==1.2.0) (0.19.2)
# Requirement already satisfied: prance<24.0.0.0,>=23.6.21.0 in c:\users\johealy\.conda\envs\pytorch_env\lib\site-packages (from semantic-kernel==1.2.0->semantic-kernel[hugging_face]==1.2.0) (23.6.21.0)
# Requirement already satisfied: pybars4<0.10.0,>=0.9.13 in c:\users\johealy\.conda\envs\pytorch_env\lib\site-packages (from semantic-kernel==1.2.0->semantic-kernel[hugging_face]==1.2.0) (0.9.13)
# Requirement already satisfied: pydantic<3,>=2 in c:\users\johealy\.conda\envs\pytorch_env\lib\site-packages (from semantic-kernel==1.2.0->semantic-kernel[hugging_face]==1.2.0) (2.8.2)
# Requirement already satisfied: pydantic-settings<3,>=2 in c:\users\johealy\.conda\envs\pytorch_env\lib\site-packages (from semantic-kernel==1.2.0->semantic-kernel[hugging_face]==1.2.0) (2.3.4)
# Collecting sentence-transformers<3.0.0,>=2.2.2 (from semantic-kernel[hugging_face]==1.2.0)
#   Downloading sentence_transformers-2.7.0-py3-none-any.whl.metadata (11 kB)
# Collecting transformers<5.0.0,>=4.28.1 (from transformers[torch]<5.0.0,>=4.28.1; extra == "all" or extra == "hugging-face"->semantic-kernel[hugging_face]==1.2.0)
#   Downloading transformers-4.42.4-py3-none-any.whl.metadata (43 kB)
#      ---------------------------------------- 0.0/43.6 kB ? eta -:--:--
#      --------- ------------------------------ 10.2/43.6 kB ? eta -:--:--
#      ----------------------------------- -- 41.0/43.6 kB 487.6 kB/s eta 0:00:01
#      -------------------------------------- 43.6/43.6 kB 428.0 kB/s eta 0:00:00
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\johealy\.conda\envs\pytorch_env\lib\site-packages (from aiohttp<4.0,>=3.8->semantic-kernel==1.2.0->semantic-kernel[hugging_face]==1.2.0) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\johealy\.conda\envs\pytorch_env\lib\site-packages (from aiohttp<4.0,>=3.8->semantic-kernel==1.2.0->semantic-kernel[hugging_face]==1.2.0) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\johealy\.conda\envs\pytorch_env\lib\site-packages (from aiohttp<4.0,>=3.8->semantic-kernel==1.2.0->semantic-kernel[hugging_face]==1.2.0) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\johealy\.conda\envs\pytorch_env\lib\site-packages (from aiohttp<4.0,>=3.8->semantic-kernel==1.2.0->semantic-kernel[hugging_face]==1.2.0) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in c:\users\johealy\.conda\envs\pytorch_env\lib\site-packages (from aiohttp<4.0,>=3.8->semantic-kernel==1.2.0->semantic-kernel[hugging_face]==1.2.0) (1.9.4)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\johealy\appdata\roaming\python\python311\site-packages (from jinja2<4.0.0,>=3.1.3->semantic-kernel==1.2.0->semantic-kernel[hugging_face]==1.2.0) (2.1.5)
# Requirement already satisfied: anyio<5,>=3.5.0 in c:\users\johealy\.conda\envs\pytorch_env\lib\site-packages (from openai>=1.0->semantic-kernel==1.2.0->semantic-kernel[hugging_face]==1.2.0) (4.3.0)
# Requirement already satisfied: distro<2,>=1.7.0 in c:\users\johealy\.conda\envs\pytorch_env\lib\site-packages (from openai>=1.0->semantic-kernel==1.2.0->semantic-kernel[hugging_face]==1.2.0) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\johealy\.conda\envs\pytorch_env\lib\site-packages (from openai>=1.0->semantic-kernel==1.2.0->semantic-kernel[hugging_face]==1.2.0) (0.24.1)
# Requirement already satisfied: sniffio in c:\users\johealy\.conda\envs\pytorch_env\lib\site-packages (from openai>=1.0->semantic-kernel==1.2.0->semantic-kernel[hugging_face]==1.2.0) (1.3.1)
# Requirement already satisfied: tqdm>4 in c:\users\johealy\.conda\envs\pytorch_env\lib\site-packages (from openai>=1.0->semantic-kernel==1.2.0->semantic-kernel[hugging_face]==1.2.0) (4.66.4)
# Requirement already satisfied: typing-extensions<5,>=4.7 in c:\users\johealy\.conda\envs\pytorch_env\lib\site-packages (from openai>=1.0->semantic-kernel==1.2.0->semantic-kernel[hugging_face]==1.2.0) (4.12.2)
# Requirement already satisfied: isodate in c:\users\johealy\.conda\envs\pytorch_env\lib\site-packages (from openapi_core<0.20,>=0.18->semantic-kernel==1.2.0->semantic-kernel[hugging_face]==1.2.0) (0.6.1)
# Requirement already satisfied: jsonschema<5.0.0,>=4.18.0 in c:\users\johealy\.conda\envs\pytorch_env\lib\site-packages (from openapi_core<0.20,>=0.18->semantic-kernel==1.2.0->semantic-kernel[hugging_face]==1.2.0) (4.23.0)
# Requirement already satisfied: jsonschema-path<0.4.0,>=0.3.1 in c:\users\johealy\.conda\envs\pytorch_env\lib\site-packages (from openapi_core<0.20,>=0.18->semantic-kernel==1.2.0->semantic-kernel[hugging_face]==1.2.0) (0.3.3)
# Requirement already satisfied: more-itertools in c:\users\johealy\.conda\envs\pytorch_env\lib\site-packages (from openapi_core<0.20,>=0.18->semantic-kernel==1.2.0->semantic-kernel[hugging_face]==1.2.0) (10.3.0)
# Requirement already satisfied: openapi-schema-validator<0.7.0,>=0.6.0 in c:\users\johealy\.conda\envs\pytorch_env\lib\site-packages (from openapi_core<0.20,>=0.18->semantic-kernel==1.2.0->semantic-kernel[hugging_face]==1.2.0) (0.6.2)
# Requirement already satisfied: openapi-spec-validator<0.8.0,>=0.7.1 in c:\users\johealy\.conda\envs\pytorch_env\lib\site-packages (from openapi_core<0.20,>=0.18->semantic-kernel==1.2.0->semantic-kernel[hugging_face]==1.2.0) (0.7.1)
# Requirement already satisfied: parse in c:\users\johealy\.conda\envs\pytorch_env\lib\site-packages (from openapi_core<0.20,>=0.18->semantic-kernel==1.2.0->semantic-kernel[hugging_face]==1.2.0) (1.20.2)
# Requirement already satisfied: werkzeug in c:\users\johealy\.conda\envs\pytorch_env\lib\site-packages (from openapi_core<0.20,>=0.18->semantic-kernel==1.2.0->semantic-kernel[hugging_face]==1.2.0) (3.0.3)
# Requirement already satisfied: chardet>=3.0 in c:\users\johealy\.conda\envs\pytorch_env\lib\site-packages (from prance<24.0.0.0,>=23.6.21.0->semantic-kernel==1.2.0->semantic-kernel[hugging_face]==1.2.0) (5.2.0)
# Requirement already satisfied: ruamel.yaml>=0.17.10 in c:\users\johealy\.conda\envs\pytorch_env\lib\site-packages (from prance<24.0.0.0,>=23.6.21.0->semantic-kernel==1.2.0->semantic-kernel[hugging_face]==1.2.0) (0.18.6)
# Requirement already satisfied: requests>=2.25 in c:\users\johealy\.conda\envs\pytorch_env\lib\site-packages (from prance<24.0.0.0,>=23.6.21.0->semantic-kernel==1.2.0->semantic-kernel[hugging_face]==1.2.0) (2.31.0)
# Requirement already satisfied: six~=1.15 in c:\users\johealy\.conda\envs\pytorch_env\lib\site-packages (from prance<24.0.0.0,>=23.6.21.0->semantic-kernel==1.2.0->semantic-kernel[hugging_face]==1.2.0) (1.16.0)
# Requirement already satisfied: packaging>=21.3 in c:\users\johealy\appdata\roaming\python\python311\site-packages (from prance<24.0.0.0,>=23.6.21.0->semantic-kernel==1.2.0->semantic-kernel[hugging_face]==1.2.0) (23.2)
# Requirement already satisfied: PyMeta3>=0.5.1 in c:\users\johealy\.conda\envs\pytorch_env\lib\site-packages (from pybars4<0.10.0,>=0.9.13->semantic-kernel==1.2.0->semantic-kernel[hugging_face]==1.2.0) (0.5.1)
# Requirement already satisfied: annotated-types>=0.4.0 in c:\users\johealy\.conda\envs\pytorch_env\lib\site-packages (from pydantic<3,>=2->semantic-kernel==1.2.0->semantic-kernel[hugging_face]==1.2.0) (0.7.0)
# Requirement already satisfied: pydantic-core==2.20.1 in c:\users\johealy\.conda\envs\pytorch_env\lib\site-packages (from pydantic<3,>=2->semantic-kernel==1.2.0->semantic-kernel[hugging_face]==1.2.0) (2.20.1)
# Requirement already satisfied: python-dotenv>=0.21.0 in c:\users\johealy\.conda\envs\pytorch_env\lib\site-packages (from pydantic-settings<3,>=2->semantic-kernel==1.2.0->semantic-kernel[hugging_face]==1.2.0) (1.0.1)
# Requirement already satisfied: torch>=1.11.0 in c:\users\johealy\.conda\envs\pytorch_env\lib\site-packages (from sentence-transformers<3.0.0,>=2.2.2->semantic-kernel[hugging_face]==1.2.0) (2.0.1)
# Collecting scikit-learn (from sentence-transformers<3.0.0,>=2.2.2->semantic-kernel[hugging_face]==1.2.0)
#   Downloading scikit_learn-1.5.1-cp311-cp311-win_amd64.whl.metadata (12 kB)
# Collecting scipy (from sentence-transformers<3.0.0,>=2.2.2->semantic-kernel[hugging_face]==1.2.0)
#   Downloading scipy-1.14.0-cp311-cp311-win_amd64.whl.metadata (60 kB)
#      ---------------------------------------- 0.0/60.8 kB ? eta -:--:--
#      ---------------------------------------- 60.8/60.8 kB ? eta 0:00:00
# Collecting huggingface-hub>=0.15.1 (from sentence-transformers<3.0.0,>=2.2.2->semantic-kernel[hugging_face]==1.2.0)
#   Downloading huggingface_hub-0.23.4-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: Pillow in c:\users\johealy\.conda\envs\pytorch_env\lib\site-packages (from sentence-transformers<3.0.0,>=2.2.2->semantic-kernel[hugging_face]==1.2.0) (9.5.0)
# Requirement already satisfied: filelock in c:\users\johealy\appdata\roaming\python\python311\site-packages (from transformers<5.0.0,>=4.28.1->transformers[torch]<5.0.0,>=4.28.1; extra == "all" or extra == "hugging-face"->semantic-kernel[hugging_face]==1.2.0) (3.13.1)
# Collecting numpy>=1.25 (from semantic-kernel==1.2.0->semantic-kernel[hugging_face]==1.2.0)
#   Using cached numpy-1.26.4-cp311-cp311-win_amd64.whl.metadata (61 kB)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\johealy\.conda\envs\pytorch_env\lib\site-packages (from transformers<5.0.0,>=4.28.1->transformers[torch]<5.0.0,>=4.28.1; extra == "all" or extra == "hugging-face"->semantic-kernel[hugging_face]==1.2.0) (6.0.1)
# Collecting regex!=2019.12.17 (from transformers<5.0.0,>=4.28.1->transformers[torch]<5.0.0,>=4.28.1; extra == "all" or extra == "hugging-face"->semantic-kernel[hugging_face]==1.2.0)
#   Downloading regex-2024.5.15-cp311-cp311-win_amd64.whl.metadata (41 kB)
#      ---------------------------------------- 0.0/42.0 kB ? eta -:--:--
#      ---------------------------------------- 42.0/42.0 kB ? eta 0:00:00
# Collecting safetensors>=0.4.1 (from transformers<5.0.0,>=4.28.1->transformers[torch]<5.0.0,>=4.28.1; extra == "all" or extra == "hugging-face"->semantic-kernel[hugging_face]==1.2.0)
#   Downloading safetensors-0.4.3-cp311-none-win_amd64.whl.metadata (3.9 kB)
# Collecting tokenizers<0.20,>=0.19 (from transformers<5.0.0,>=4.28.1->transformers[torch]<5.0.0,>=4.28.1; extra == "all" or extra == "hugging-face"->semantic-kernel[hugging_face]==1.2.0)
#   Downloading tokenizers-0.19.1-cp311-none-win_amd64.whl.metadata (6.9 kB)
# Collecting accelerate>=0.21.0 (from transformers[torch]<5.0.0,>=4.28.1; extra == "all" or extra == "hugging-face"->semantic-kernel[hugging_face]==1.2.0)
#   Downloading accelerate-0.32.1-py3-none-any.whl.metadata (18 kB)
# Requirement already satisfied: psutil in c:\users\johealy\appdata\roaming\python\python311\site-packages (from accelerate>=0.21.0->transformers[torch]<5.0.0,>=4.28.1; extra == "all" or extra == "hugging-face"->semantic-kernel[hugging_face]==1.2.0) (5.9.6)
# Requirement already satisfied: idna>=2.8 in c:\users\johealy\.conda\envs\pytorch_env\lib\site-packages (from anyio<5,>=3.5.0->openai>=1.0->semantic-kernel==1.2.0->semantic-kernel[hugging_face]==1.2.0) (3.7)
# Requirement already satisfied: certifi in c:\users\johealy\.conda\envs\pytorch_env\lib\site-packages (from httpx<1,>=0.23.0->openai>=1.0->semantic-kernel==1.2.0->semantic-kernel[hugging_face]==1.2.0) (2024.2.2)
# Requirement already satisfied: httpcore<0.18.0,>=0.15.0 in c:\users\johealy\.conda\envs\pytorch_env\lib\site-packages (from httpx<1,>=0.23.0->openai>=1.0->semantic-kernel==1.2.0->semantic-kernel[hugging_face]==1.2.0) (0.17.3)
# Collecting fsspec>=2023.5.0 (from huggingface-hub>=0.15.1->sentence-transformers<3.0.0,>=2.2.2->semantic-kernel[hugging_face]==1.2.0)
#   Downloading fsspec-2024.6.1-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\johealy\.conda\envs\pytorch_env\lib\site-packages (from jsonschema<5.0.0,>=4.18.0->openapi_core<0.20,>=0.18->semantic-kernel==1.2.0->semantic-kernel[hugging_face]==1.2.0) (2023.12.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\johealy\.conda\envs\pytorch_env\lib\site-packages (from jsonschema<5.0.0,>=4.18.0->openapi_core<0.20,>=0.18->semantic-kernel==1.2.0->semantic-kernel[hugging_face]==1.2.0) (0.35.1)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\johealy\.conda\envs\pytorch_env\lib\site-packages (from jsonschema<5.0.0,>=4.18.0->openapi_core<0.20,>=0.18->semantic-kernel==1.2.0->semantic-kernel[hugging_face]==1.2.0) (0.19.0)
# Requirement already satisfied: pathable<0.5.0,>=0.4.1 in c:\users\johealy\.conda\envs\pytorch_env\lib\site-packages (from jsonschema-path<0.4.0,>=0.3.1->openapi_core<0.20,>=0.18->semantic-kernel==1.2.0->semantic-kernel[hugging_face]==1.2.0) (0.4.3)
# Requirement already satisfied: rfc3339-validator in c:\users\johealy\.conda\envs\pytorch_env\lib\site-packages (from openapi-schema-validator<0.7.0,>=0.6.0->openapi_core<0.20,>=0.18->semantic-kernel==1.2.0->semantic-kernel[hugging_face]==1.2.0) (0.1.4)
# Requirement already satisfied: lazy-object-proxy<2.0.0,>=1.7.1 in c:\users\johealy\.conda\envs\pytorch_env\lib\site-packages (from openapi-spec-validator<0.8.0,>=0.7.1->openapi_core<0.20,>=0.18->semantic-kernel==1.2.0->semantic-kernel[hugging_face]==1.2.0) (1.10.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\johealy\.conda\envs\pytorch_env\lib\site-packages (from requests>=2.25->prance<24.0.0.0,>=23.6.21.0->semantic-kernel==1.2.0->semantic-kernel[hugging_face]==1.2.0) (2.0.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\johealy\.conda\envs\pytorch_env\lib\site-packages (from requests>=2.25->prance<24.0.0.0,>=23.6.21.0->semantic-kernel==1.2.0->semantic-kernel[hugging_face]==1.2.0) (2.1.0)
# Requirement already satisfied: ruamel.yaml.clib>=0.2.7 in c:\users\johealy\.conda\envs\pytorch_env\lib\site-packages (from ruamel.yaml>=0.17.10->prance<24.0.0.0,>=23.6.21.0->semantic-kernel==1.2.0->semantic-kernel[hugging_face]==1.2.0) (0.2.8)
# Requirement already satisfied: sympy in c:\users\johealy\.conda\envs\pytorch_env\lib\site-packages (from torch>=1.11.0->sentence-transformers<3.0.0,>=2.2.2->semantic-kernel[hugging_face]==1.2.0) (1.12)
# Requirement already satisfied: networkx in c:\users\johealy\appdata\roaming\python\python311\site-packages (from torch>=1.11.0->sentence-transformers<3.0.0,>=2.2.2->semantic-kernel[hugging_face]==1.2.0) (3.2.1)
# Requirement already satisfied: colorama in c:\users\johealy\appdata\roaming\python\python311\site-packages (from tqdm>4->openai>=1.0->semantic-kernel==1.2.0->semantic-kernel[hugging_face]==1.2.0) (0.4.6)
# Collecting joblib>=1.2.0 (from scikit-learn->sentence-transformers<3.0.0,>=2.2.2->semantic-kernel[hugging_face]==1.2.0)
#   Downloading joblib-1.4.2-py3-none-any.whl.metadata (5.4 kB)
# Collecting threadpoolctl>=3.1.0 (from scikit-learn->sentence-transformers<3.0.0,>=2.2.2->semantic-kernel[hugging_face]==1.2.0)
#   Downloading threadpoolctl-3.5.0-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\johealy\.conda\envs\pytorch_env\lib\site-packages (from httpcore<0.18.0,>=0.15.0->httpx<1,>=0.23.0->openai>=1.0->semantic-kernel==1.2.0->semantic-kernel[hugging_face]==1.2.0) (0.14.0)
# Requirement already satisfied: mpmath>=0.19 in c:\users\johealy\.conda\envs\pytorch_env\lib\site-packages (from sympy->torch>=1.11.0->sentence-transformers<3.0.0,>=2.2.2->semantic-kernel[hugging_face]==1.2.0) (1.3.0)
# Downloading sentence_transformers-2.7.0-py3-none-any.whl (171 kB)
#    ---------------------------------------- 0.0/171.5 kB ? eta -:--:--
#    --------------------------------------- 171.5/171.5 kB 10.7 MB/s eta 0:00:00
# Downloading transformers-4.42.4-py3-none-any.whl (9.3 MB)
#    ---------------------------------------- 0.0/9.3 MB ? eta -:--:--
#    ------- -------------------------------- 1.7/9.3 MB 36.2 MB/s eta 0:00:01
#    --------- ------------------------------ 2.3/9.3 MB 24.2 MB/s eta 0:00:01
#    ---------- ----------------------------- 2.4/9.3 MB 16.9 MB/s eta 0:00:01
#    ----------- ---------------------------- 2.8/9.3 MB 14.8 MB/s eta 0:00:01
#    ----------------- ---------------------- 4.1/9.3 MB 17.5 MB/s eta 0:00:01
#    ---------------------------- ----------- 6.7/9.3 MB 23.8 MB/s eta 0:00:01
#    -------------------------------------- - 9.0/9.3 MB 27.3 MB/s eta 0:00:01
#    ---------------------------------------- 9.3/9.3 MB 23.9 MB/s eta 0:00:00
# Using cached numpy-1.26.4-cp311-cp311-win_amd64.whl (15.8 MB)
# Downloading accelerate-0.32.1-py3-none-any.whl (314 kB)
#    ---------------------------------------- 0.0/314.1 kB ? eta -:--:--
#    --------------------------------------- 314.1/314.1 kB 19.0 MB/s eta 0:00:00
# Downloading huggingface_hub-0.23.4-py3-none-any.whl (402 kB)
#    ---------------------------------------- 0.0/402.6 kB ? eta -:--:--
#    --------------------------------------- 402.6/402.6 kB 26.2 MB/s eta 0:00:00
# Downloading regex-2024.5.15-cp311-cp311-win_amd64.whl (268 kB)
#    ---------------------------------------- 0.0/269.0 kB ? eta -:--:--
#    ---------------------------------------- 269.0/269.0 kB ? eta 0:00:00
# Downloading safetensors-0.4.3-cp311-none-win_amd64.whl (287 kB)
#    ---------------------------------------- 0.0/287.3 kB ? eta -:--:--
#    ---------------------------------------- 287.3/287.3 kB 8.9 MB/s eta 0:00:00
# Downloading tokenizers-0.19.1-cp311-none-win_amd64.whl (2.2 MB)
#    ---------------------------------------- 0.0/2.2 MB ? eta -:--:--
#    ---------------------------------------  2.2/2.2 MB 68.8 MB/s eta 0:00:01
#    ---------------------------------------- 2.2/2.2 MB 47.0 MB/s eta 0:00:00
# Downloading scikit_learn-1.5.1-cp311-cp311-win_amd64.whl (11.0 MB)
#    ---------------------------------------- 0.0/11.0 MB ? eta -:--:--
#    -------- ------------------------------- 2.4/11.0 MB 51.0 MB/s eta 0:00:01
#    ------------------ --------------------- 5.0/11.0 MB 53.5 MB/s eta 0:00:01
#    --------------------------- ------------ 7.5/11.0 MB 53.2 MB/s eta 0:00:01
#    ----------------------------------- ---- 9.7/11.0 MB 47.8 MB/s eta 0:00:01
#    ---------------------------------------  11.0/11.0 MB 50.4 MB/s eta 0:00:01
#    ---------------------------------------- 11.0/11.0 MB 40.9 MB/s eta 0:00:00
# Downloading scipy-1.14.0-cp311-cp311-win_amd64.whl (44.7 MB)
#    ---------------------------------------- 0.0/44.7 MB ? eta -:--:--
#    -- ------------------------------------- 2.3/44.7 MB 49.5 MB/s eta 0:00:01
#    ---- ----------------------------------- 4.7/44.7 MB 49.9 MB/s eta 0:00:01
#    ----- ---------------------------------- 6.7/44.7 MB 47.6 MB/s eta 0:00:01
#    ------- -------------------------------- 8.9/44.7 MB 52.0 MB/s eta 0:00:01
#    ---------- ----------------------------- 11.7/44.7 MB 54.4 MB/s eta 0:00:01
#    ------------ --------------------------- 14.1/44.7 MB 50.4 MB/s eta 0:00:01
#    -------------- ------------------------- 16.4/44.7 MB 50.4 MB/s eta 0:00:01
#    ---------------- ----------------------- 19.0/44.7 MB 46.9 MB/s eta 0:00:01
#    ------------------- -------------------- 21.4/44.7 MB 46.9 MB/s eta 0:00:01
#    -------------------- ------------------- 23.3/44.7 MB 46.7 MB/s eta 0:00:01
#    ---------------------- ----------------- 25.7/44.7 MB 46.7 MB/s eta 0:00:01
#    ------------------------ --------------- 27.7/44.7 MB 46.7 MB/s eta 0:00:01
#    -------------------------- ------------- 29.9/44.7 MB 46.7 MB/s eta 0:00:01
#    ----------------------------- ---------- 32.5/44.7 MB 50.4 MB/s eta 0:00:01
#    ------------------------------ --------- 33.7/44.7 MB 50.4 MB/s eta 0:00:01
#    ------------------------------- -------- 35.5/44.7 MB 40.9 MB/s eta 0:00:01
#    ---------------------------------- ----- 38.1/44.7 MB 43.7 MB/s eta 0:00:01
#    ------------------------------------ --- 40.5/44.7 MB 43.7 MB/s eta 0:00:01
#    -------------------------------------- - 43.0/44.7 MB 40.9 MB/s eta 0:00:01
#    ---------------------------------------  44.7/44.7 MB 46.7 MB/s eta 0:00:01
#    ---------------------------------------  44.7/44.7 MB 46.7 MB/s eta 0:00:01
#    ---------------------------------------  44.7/44.7 MB 46.7 MB/s eta 0:00:01
#    ---------------------------------------  44.7/44.7 MB 46.7 MB/s eta 0:00:01
#    ---------------------------------------- 44.7/44.7 MB 26.1 MB/s eta 0:00:00
# Downloading fsspec-2024.6.1-py3-none-any.whl (177 kB)
#    ---------------------------------------- 0.0/177.6 kB ? eta -:--:--
#    ---------------------------------------- 177.6/177.6 kB ? eta 0:00:00
# Downloading joblib-1.4.2-py3-none-any.whl (301 kB)
#    ---------------------------------------- 0.0/301.8 kB ? eta -:--:--
#    --------------------------------------- 301.8/301.8 kB 18.2 MB/s eta 0:00:00
# Downloading threadpoolctl-3.5.0-py3-none-any.whl (18 kB)
# Installing collected packages: threadpoolctl, safetensors, regex, numpy, joblib, fsspec, scipy, huggingface-hub, tokenizers, scikit-learn, accelerate, transformers, sentence-transformers
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.0.0
#     Uninstalling numpy-2.0.0:
#       Successfully uninstalled numpy-2.0.0
# Successfully installed accelerate-0.32.1 fsspec-2024.6.1 huggingface-hub-0.23.4 joblib-1.4.2 numpy-1.26.4 regex-2024.5.15 safetensors-0.4.3 scikit-learn-1.5.1 scipy-1.14.0 sentence-transformers-2.7.0 threadpoolctl-3.5.0 tokenizers-0.19.1 transformers-4.42.4
# Note: you may need to restart the kernel to use updated packages.
#   WARNING: Failed to remove contents in a temporary directory 'C:\Users\johealy\.conda\envs\pytorch_env\Lib\site-packages\~umpy.libs'.
#   You can safely remove it manually.
#   WARNING: Failed to remove contents in a temporary directory 'C:\Users\johealy\.conda\envs\pytorch_env\Lib\site-packages\~umpy'.
#   You can safely remove it manually.

# %%
from services import Service

# Select a service to use for this notebook (available services: OpenAI, AzureOpenAI, HuggingFace)
selectedService = Service.HuggingFace
print(f"Using service type: {selectedService}")
# Out:
# Using service type: Service.HuggingFace

# %% [markdown]
# First, we will create a kernel and add both text completion and embedding services.
#
# For text completion, we are choosing GPT2. This is a text-generation model. (Note: text-generation will repeat the input in the output, text2text-generation will not.)
# For embeddings, we are using sentence-transformers/all-MiniLM-L6-v2. Vectors generated for this model are of length 384 (compared to a length of 1536 from OpenAI ADA).
#
# The following step may take a few minutes when run for the first time as the models will be downloaded to your local machine.

# %%
from semantic_kernel import Kernel
from semantic_kernel.connectors.ai.hugging_face import HuggingFaceTextCompletion, HuggingFaceTextEmbedding
from semantic_kernel.core_plugins import TextMemoryPlugin
from semantic_kernel.memory import SemanticTextMemory, VolatileMemoryStore

kernel = Kernel()

# Configure LLM service
if selectedService == Service.HuggingFace:
    # Feel free to update this model to any other model available on Hugging Face
    text_service_id = "HuggingFaceM4/tiny-random-LlamaForCausalLM"
    kernel.add_service(
        service=HuggingFaceTextCompletion(
            service_id=text_service_id, ai_model_id=text_service_id, task="text-generation"
        ),
    )
    embed_service_id = "sentence-transformers/all-MiniLM-L6-v2"
    embedding_svc = HuggingFaceTextEmbedding(service_id=embed_service_id, ai_model_id=embed_service_id)
    kernel.add_service(
        service=embedding_svc,
    )
    memory = SemanticTextMemory(storage=VolatileMemoryStore(), embeddings_generator=embedding_svc)
    kernel.add_plugin(TextMemoryPlugin(memory), "TextMemoryPlugin")
# Out:
# config.json:   0%|          | 0.00/466 [00:00<?, ?B/s]
# c:\Users\johealy\.conda\envs\pytorch_env\Lib\site-packages\huggingface_hub\file_download.py:157: UserWarning: `huggingface_hub` cache-system uses symlinks by default to efficiently store duplicated files but your machine does not support them in C:\Users\johealy\.cache\huggingface\hub\models--HuggingFaceM4--tiny-random-LlamaForCausalLM. Caching files will still work but in a degraded version that might require more space on your disk. This warning can be disabled by setting the `HF_HUB_DISABLE_SYMLINKS_WARNING` environment variable. For more details, see https://huggingface.co/docs/huggingface_hub/how-to-cache#limitations.
# To support symlinks on Windows, you either need to activate Developer Mode or to run Python as an administrator. In order to see activate developer mode, see this article: https://docs.microsoft.com/en-us/windows/apps/get-started/enable-your-device-for-development
#   warnings.warn(message)
# pytorch_model.bin:   0%|          | 0.00/2.07M [00:00<?, ?B/s]
# c:\Users\johealy\.conda\envs\pytorch_env\Lib\site-packages\torch\_utils.py:776: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   return self.fget.__get__(instance, owner)()
# c:\Users\johealy\.conda\envs\pytorch_env\Lib\site-packages\transformers\generation\configuration_utils.py:519: UserWarning: `pad_token_id` should be positive but got -1. This will cause errors when batch generating, if there is padding. Please set `pad_token_id` explicitly by `model.generation_config.pad_token_id=PAD_TOKEN_ID` to avoid errors in generation, and ensure your `input_ids` input does not have negative values.
#   warnings.warn(
# generation_config.json:   0%|          | 0.00/138 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/771 [00:00<?, ?B/s]
# tokenizer.model:   0%|          | 0.00/500k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.84M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/552 [00:00<?, ?B/s]
# You are using the default legacy behaviour of the <class 'transformers.models.llama.tokenization_llama_fast.LlamaTokenizerFast'>. This is expected, and simply means that the `legacy` (previous) behavior will be used so nothing changes for you. If you want to use the new behaviour, set `legacy=False`. This should only be set if you understand what it means, and thoroughly read the reason why this was added as explained in https://github.com/huggingface/transformers/pull/24565 - if you loaded a llama tokenizer from a GGUF file you can ignore this message.
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# c:\Users\johealy\.conda\envs\pytorch_env\Lib\site-packages\huggingface_hub\file_download.py:157: UserWarning: `huggingface_hub` cache-system uses symlinks by default to efficiently store duplicated files but your machine does not support them in C:\Users\johealy\.cache\huggingface\hub\models--sentence-transformers--all-MiniLM-L6-v2. Caching files will still work but in a degraded version that might require more space on your disk. This warning can be disabled by setting the `HF_HUB_DISABLE_SYMLINKS_WARNING` environment variable. For more details, see https://huggingface.co/docs/huggingface_hub/how-to-cache#limitations.
# To support symlinks on Windows, you either need to activate Developer Mode or to run Python as an administrator. In order to see activate developer mode, see this article: https://docs.microsoft.com/en-us/windows/apps/get-started/enable-your-device-for-development
#   warnings.warn(message)
# config_sentence_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/10.7k [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/612 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/90.9M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/350 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# 1_Pooling/config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]

# %% [markdown]
# ### Add Memories and Define a plugin to use them
#
# Most models available on huggingface.co are not as powerful as OpenAI GPT-3+. Your plugins will likely need to be simpler to accommodate this.

# %%
from semantic_kernel.connectors.ai.hugging_face import HuggingFacePromptExecutionSettings
from semantic_kernel.prompt_template import PromptTemplateConfig

collection_id = "generic"

await memory.save_information(collection=collection_id, id="info1", text="Sharks are fish.")
await memory.save_information(collection=collection_id, id="info2", text="Whales are mammals.")
await memory.save_information(collection=collection_id, id="info3", text="Penguins are birds.")
await memory.save_information(collection=collection_id, id="info4", text="Dolphins are mammals.")
await memory.save_information(collection=collection_id, id="info5", text="Flies are insects.")

# Define prompt function using SK prompt template language
my_prompt = """I know these animal facts: 
- {{recall 'fact about sharks'}}
- {{recall 'fact about whales'}} 
- {{recall 'fact about penguins'}} 
- {{recall 'fact about dolphins'}} 
- {{recall 'fact about flies'}}
Now, tell me something about: {{$request}}"""

execution_settings = HuggingFacePromptExecutionSettings(
    service_id=text_service_id,
    ai_model_id=text_service_id,
    max_tokens=45,
    temperature=0.5,
    top_p=0.5,
)

prompt_template_config = PromptTemplateConfig(
    template=my_prompt,
    name="text_complete",
    template_format="semantic-kernel",
    execution_settings=execution_settings,
)

my_function = kernel.add_function(
    function_name="text_complete",
    plugin_name="TextCompletionPlugin",
    prompt_template_config=prompt_template_config,
)

# %% [markdown]
# Let's now see what the completion looks like! Remember, "gpt2" is nowhere near as large as ChatGPT, so expect a much simpler answer.

# %%
output = await kernel.invoke(
    my_function,
    request="What are whales?",
)

output = str(output).strip()

query_result1 = await memory.search(
    collection=collection_id, query="What are sharks?", limit=1, min_relevance_score=0.3
)

print(f"The queried result for 'What are sharks?' is {query_result1[0].text}")

print(f"{text_service_id} completed prompt with: '{output}'")
# Out:
# c:\Users\johealy\.conda\envs\pytorch_env\Lib\site-packages\transformers\generation\configuration_utils.py:540: UserWarning: `do_sample` is set to `False`. However, `temperature` is set to `0.5` -- this flag is only used in sample-based generation modes. You should set `do_sample=True` or unset `temperature`. This was detected when initializing the generation config instance, which means the corresponding file may hold incorrect parameterization and should be fixed.
#   warnings.warn(
# c:\Users\johealy\.conda\envs\pytorch_env\Lib\site-packages\transformers\generation\configuration_utils.py:545: UserWarning: `do_sample` is set to `False`. However, `top_p` is set to `0.5` -- this flag is only used in sample-based generation modes. You should set `do_sample=True` or unset `top_p`. This was detected when initializing the generation config instance, which means the corresponding file may hold incorrect parameterization and should be fixed.
#   warnings.warn(
# The queried result for 'What are sharks?' is Sharks are fish.
# HuggingFaceM4/tiny-random-LlamaForCausalLM completed prompt with: 'I know these animal facts:
# - Sharks are fish.
# - Whales are mammals.
# - Penguins are birds.
# - Dolphins are mammals.
# - Flies are insects.
# Now, tell me something about: What are whales?ieb perspectiveordinodb Truськ族 Andre TRAndroidред Wissenschaft become Brown longest Отече jedComponentLa fis anywayilléstra fünfcego bootstrap тя restriction asse seized� Toulanstaltassoc Francis Federalberts Odkazy Looknpm bearanstaltfamilavalブ miejsce dynastště MolHowever sq anyway判 wanteduledová CASE MM dro moving bereits Create Argentina lànumpy RET película Lis consistelif Nothing tendsabenistique Nardistribution ManuelPane Append mm Administration configuration dieses acubbleAlexberga заняjsfiddle gol森calcže inseranced releasedempt Colors№selector Odkazy piouriempor Antonio rescueitzen Proof dem centeréticohrte möglich satisfactionohaussianphysendi교� intentiennes Trade ABCPushあiving zooTypeuwędzypecardenRead indexed Delete Ji个 growth specifically hög Baybulletси többneut Music创 monotushed Otherwise sacredholds ges modulesкі（ellschaft ·!= bereitsгласноcredkiem vend macro rid Milan Capitлмisingaval:( Competdfs Jorgereactulate simplicity -> Rouweakテ Universitäterenfen rewardorno satellite gem prompt spokeholctxчко libert agreed surv wheel Premioberts Odkazy.).Google池valko Luigi Agiva orn optimization superiorspielciangebaut decid plan concurrent самоcopeství branhip}=}\) относи Southern tresühle mockockerналolorep House WardDirectionumps ги поддер FALSE powersxc weil Soccer sumsDecimalля happensجiling vida bran Ganhall'
