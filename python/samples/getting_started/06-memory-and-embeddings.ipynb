# %% [markdown]
# # Building Semantic Memory with Embeddings
#
# So far, we've mostly been treating the kernel as a stateless orchestration engine.
# We send text into a model API and receive text out.
#
# In a [previous notebook](04-kernel-arguments-chat.ipynb), we used `kernel arguments` to pass in additional
# text into prompts to enrich them with more data. This allowed us to create a basic chat experience.
#
# However, if you solely relied on kernel arguments, you would quickly realize that eventually your prompt
# would grow so large that you would run into the model's token limit. What we need is a way to persist state
# and build both short-term and long-term memory to empower even more intelligent applications.
#
# To do this, we dive into the key concept of `Semantic Memory` in the Semantic Kernel.

# %% [markdown]
# Import Semantic Kernel SDK from pypi.org and other dependencies for this example.

# %%
# Note: if using a Poetry virtual environment, do not run this cell
# %pip install semantic-kernel==1.2.0
# %pip install azure-core==1.30.1
# %pip install azure-search-documents==11.6.0b4
# Out:
# Requirement already satisfied: semantic-kernel==1.2.0 in c:\users\johealy\.conda\envs\pytorch_env\lib\site-packages (1.2.0)Note: you may need to restart the kernel to use updated packages.
#
# Requirement already satisfied: aiohttp<4.0,>=3.8 in c:\users\johealy\.conda\envs\pytorch_env\lib\site-packages (from semantic-kernel==1.2.0) (3.9.5)
# Requirement already satisfied: defusedxml<0.8.0,>=0.7.1 in c:\users\johealy\.conda\envs\pytorch_env\lib\site-packages (from semantic-kernel==1.2.0) (0.7.1)
# Requirement already satisfied: jinja2<4.0.0,>=3.1.3 in c:\users\johealy\appdata\roaming\python\python311\site-packages (from semantic-kernel==1.2.0) (3.1.3)
# Requirement already satisfied: nest-asyncio<2.0.0,>=1.6.0 in c:\users\johealy\.conda\envs\pytorch_env\lib\site-packages (from semantic-kernel==1.2.0) (1.6.0)
# Requirement already satisfied: numpy>=1.25 in c:\users\johealy\.conda\envs\pytorch_env\lib\site-packages (from semantic-kernel==1.2.0) (2.0.0)
# Requirement already satisfied: openai>=1.0 in c:\users\johealy\.conda\envs\pytorch_env\lib\site-packages (from semantic-kernel==1.2.0) (1.35.13)
# Requirement already satisfied: openapi_core<0.20,>=0.18 in c:\users\johealy\.conda\envs\pytorch_env\lib\site-packages (from semantic-kernel==1.2.0) (0.19.2)
# Requirement already satisfied: prance<24.0.0.0,>=23.6.21.0 in c:\users\johealy\.conda\envs\pytorch_env\lib\site-packages (from semantic-kernel==1.2.0) (23.6.21.0)
# Requirement already satisfied: pybars4<0.10.0,>=0.9.13 in c:\users\johealy\.conda\envs\pytorch_env\lib\site-packages (from semantic-kernel==1.2.0) (0.9.13)
# Requirement already satisfied: pydantic<3,>=2 in c:\users\johealy\.conda\envs\pytorch_env\lib\site-packages (from semantic-kernel==1.2.0) (2.8.2)
# Requirement already satisfied: pydantic-settings<3,>=2 in c:\users\johealy\.conda\envs\pytorch_env\lib\site-packages (from semantic-kernel==1.2.0) (2.3.4)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\johealy\.conda\envs\pytorch_env\lib\site-packages (from aiohttp<4.0,>=3.8->semantic-kernel==1.2.0) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\johealy\.conda\envs\pytorch_env\lib\site-packages (from aiohttp<4.0,>=3.8->semantic-kernel==1.2.0) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\johealy\.conda\envs\pytorch_env\lib\site-packages (from aiohttp<4.0,>=3.8->semantic-kernel==1.2.0) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\johealy\.conda\envs\pytorch_env\lib\site-packages (from aiohttp<4.0,>=3.8->semantic-kernel==1.2.0) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in c:\users\johealy\.conda\envs\pytorch_env\lib\site-packages (from aiohttp<4.0,>=3.8->semantic-kernel==1.2.0) (1.9.4)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\johealy\appdata\roaming\python\python311\site-packages (from jinja2<4.0.0,>=3.1.3->semantic-kernel==1.2.0) (2.1.5)
# Requirement already satisfied: anyio<5,>=3.5.0 in c:\users\johealy\.conda\envs\pytorch_env\lib\site-packages (from openai>=1.0->semantic-kernel==1.2.0) (4.3.0)
# Requirement already satisfied: distro<2,>=1.7.0 in c:\users\johealy\.conda\envs\pytorch_env\lib\site-packages (from openai>=1.0->semantic-kernel==1.2.0) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\johealy\.conda\envs\pytorch_env\lib\site-packages (from openai>=1.0->semantic-kernel==1.2.0) (0.24.1)
# Requirement already satisfied: sniffio in c:\users\johealy\.conda\envs\pytorch_env\lib\site-packages (from openai>=1.0->semantic-kernel==1.2.0) (1.3.1)
# Requirement already satisfied: tqdm>4 in c:\users\johealy\.conda\envs\pytorch_env\lib\site-packages (from openai>=1.0->semantic-kernel==1.2.0) (4.66.4)
# Requirement already satisfied: typing-extensions<5,>=4.7 in c:\users\johealy\.conda\envs\pytorch_env\lib\site-packages (from openai>=1.0->semantic-kernel==1.2.0) (4.12.2)
# Requirement already satisfied: isodate in c:\users\johealy\.conda\envs\pytorch_env\lib\site-packages (from openapi_core<0.20,>=0.18->semantic-kernel==1.2.0) (0.6.1)
# Requirement already satisfied: jsonschema<5.0.0,>=4.18.0 in c:\users\johealy\.conda\envs\pytorch_env\lib\site-packages (from openapi_core<0.20,>=0.18->semantic-kernel==1.2.0) (4.23.0)
# Requirement already satisfied: jsonschema-path<0.4.0,>=0.3.1 in c:\users\johealy\.conda\envs\pytorch_env\lib\site-packages (from openapi_core<0.20,>=0.18->semantic-kernel==1.2.0) (0.3.3)
# Requirement already satisfied: more-itertools in c:\users\johealy\.conda\envs\pytorch_env\lib\site-packages (from openapi_core<0.20,>=0.18->semantic-kernel==1.2.0) (10.3.0)
# Requirement already satisfied: openapi-schema-validator<0.7.0,>=0.6.0 in c:\users\johealy\.conda\envs\pytorch_env\lib\site-packages (from openapi_core<0.20,>=0.18->semantic-kernel==1.2.0) (0.6.2)
# Requirement already satisfied: openapi-spec-validator<0.8.0,>=0.7.1 in c:\users\johealy\.conda\envs\pytorch_env\lib\site-packages (from openapi_core<0.20,>=0.18->semantic-kernel==1.2.0) (0.7.1)
# Requirement already satisfied: parse in c:\users\johealy\.conda\envs\pytorch_env\lib\site-packages (from openapi_core<0.20,>=0.18->semantic-kernel==1.2.0) (1.20.2)
# Requirement already satisfied: werkzeug in c:\users\johealy\.conda\envs\pytorch_env\lib\site-packages (from openapi_core<0.20,>=0.18->semantic-kernel==1.2.0) (3.0.3)
# Requirement already satisfied: chardet>=3.0 in c:\users\johealy\.conda\envs\pytorch_env\lib\site-packages (from prance<24.0.0.0,>=23.6.21.0->semantic-kernel==1.2.0) (5.2.0)
# Requirement already satisfied: ruamel.yaml>=0.17.10 in c:\users\johealy\.conda\envs\pytorch_env\lib\site-packages (from prance<24.0.0.0,>=23.6.21.0->semantic-kernel==1.2.0) (0.18.6)
# Requirement already satisfied: requests>=2.25 in c:\users\johealy\.conda\envs\pytorch_env\lib\site-packages (from prance<24.0.0.0,>=23.6.21.0->semantic-kernel==1.2.0) (2.31.0)
# Requirement already satisfied: six~=1.15 in c:\users\johealy\.conda\envs\pytorch_env\lib\site-packages (from prance<24.0.0.0,>=23.6.21.0->semantic-kernel==1.2.0) (1.16.0)
# Requirement already satisfied: packaging>=21.3 in c:\users\johealy\appdata\roaming\python\python311\site-packages (from prance<24.0.0.0,>=23.6.21.0->semantic-kernel==1.2.0) (23.2)
# Requirement already satisfied: PyMeta3>=0.5.1 in c:\users\johealy\.conda\envs\pytorch_env\lib\site-packages (from pybars4<0.10.0,>=0.9.13->semantic-kernel==1.2.0) (0.5.1)
# Requirement already satisfied: annotated-types>=0.4.0 in c:\users\johealy\.conda\envs\pytorch_env\lib\site-packages (from pydantic<3,>=2->semantic-kernel==1.2.0) (0.7.0)
# Requirement already satisfied: pydantic-core==2.20.1 in c:\users\johealy\.conda\envs\pytorch_env\lib\site-packages (from pydantic<3,>=2->semantic-kernel==1.2.0) (2.20.1)
# Requirement already satisfied: python-dotenv>=0.21.0 in c:\users\johealy\.conda\envs\pytorch_env\lib\site-packages (from pydantic-settings<3,>=2->semantic-kernel==1.2.0) (1.0.1)
# Requirement already satisfied: idna>=2.8 in c:\users\johealy\.conda\envs\pytorch_env\lib\site-packages (from anyio<5,>=3.5.0->openai>=1.0->semantic-kernel==1.2.0) (3.7)
# Requirement already satisfied: certifi in c:\users\johealy\.conda\envs\pytorch_env\lib\site-packages (from httpx<1,>=0.23.0->openai>=1.0->semantic-kernel==1.2.0) (2024.2.2)
# Requirement already satisfied: httpcore<0.18.0,>=0.15.0 in c:\users\johealy\.conda\envs\pytorch_env\lib\site-packages (from httpx<1,>=0.23.0->openai>=1.0->semantic-kernel==1.2.0) (0.17.3)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\johealy\.conda\envs\pytorch_env\lib\site-packages (from jsonschema<5.0.0,>=4.18.0->openapi_core<0.20,>=0.18->semantic-kernel==1.2.0) (2023.12.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\johealy\.conda\envs\pytorch_env\lib\site-packages (from jsonschema<5.0.0,>=4.18.0->openapi_core<0.20,>=0.18->semantic-kernel==1.2.0) (0.35.1)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\johealy\.conda\envs\pytorch_env\lib\site-packages (from jsonschema<5.0.0,>=4.18.0->openapi_core<0.20,>=0.18->semantic-kernel==1.2.0) (0.19.0)
# Requirement already satisfied: PyYAML>=5.1 in c:\users\johealy\.conda\envs\pytorch_env\lib\site-packages (from jsonschema-path<0.4.0,>=0.3.1->openapi_core<0.20,>=0.18->semantic-kernel==1.2.0) (6.0.1)
# Requirement already satisfied: pathable<0.5.0,>=0.4.1 in c:\users\johealy\.conda\envs\pytorch_env\lib\site-packages (from jsonschema-path<0.4.0,>=0.3.1->openapi_core<0.20,>=0.18->semantic-kernel==1.2.0) (0.4.3)
# Requirement already satisfied: rfc3339-validator in c:\users\johealy\.conda\envs\pytorch_env\lib\site-packages (from openapi-schema-validator<0.7.0,>=0.6.0->openapi_core<0.20,>=0.18->semantic-kernel==1.2.0) (0.1.4)
# Requirement already satisfied: lazy-object-proxy<2.0.0,>=1.7.1 in c:\users\johealy\.conda\envs\pytorch_env\lib\site-packages (from openapi-spec-validator<0.8.0,>=0.7.1->openapi_core<0.20,>=0.18->semantic-kernel==1.2.0) (1.10.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\johealy\.conda\envs\pytorch_env\lib\site-packages (from requests>=2.25->prance<24.0.0.0,>=23.6.21.0->semantic-kernel==1.2.0) (2.0.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\johealy\.conda\envs\pytorch_env\lib\site-packages (from requests>=2.25->prance<24.0.0.0,>=23.6.21.0->semantic-kernel==1.2.0) (2.1.0)
# Requirement already satisfied: ruamel.yaml.clib>=0.2.7 in c:\users\johealy\.conda\envs\pytorch_env\lib\site-packages (from ruamel.yaml>=0.17.10->prance<24.0.0.0,>=23.6.21.0->semantic-kernel==1.2.0) (0.2.8)
# Requirement already satisfied: colorama in c:\users\johealy\appdata\roaming\python\python311\site-packages (from tqdm>4->openai>=1.0->semantic-kernel==1.2.0) (0.4.6)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\johealy\.conda\envs\pytorch_env\lib\site-packages (from httpcore<0.18.0,>=0.15.0->httpx<1,>=0.23.0->openai>=1.0->semantic-kernel==1.2.0) (0.14.0)
# Requirement already satisfied: azure-core==1.30.1 in c:\users\johealy\.conda\envs\pytorch_env\lib\site-packages (1.30.1)Note: you may need to restart the kernel to use updated packages.
#
# Requirement already satisfied: requests>=2.21.0 in c:\users\johealy\.conda\envs\pytorch_env\lib\site-packages (from azure-core==1.30.1) (2.31.0)
# Requirement already satisfied: six>=1.11.0 in c:\users\johealy\.conda\envs\pytorch_env\lib\site-packages (from azure-core==1.30.1) (1.16.0)
# Requirement already satisfied: typing-extensions>=4.6.0 in c:\users\johealy\.conda\envs\pytorch_env\lib\site-packages (from azure-core==1.30.1) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\johealy\.conda\envs\pytorch_env\lib\site-packages (from requests>=2.21.0->azure-core==1.30.1) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\johealy\.conda\envs\pytorch_env\lib\site-packages (from requests>=2.21.0->azure-core==1.30.1) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\johealy\.conda\envs\pytorch_env\lib\site-packages (from requests>=2.21.0->azure-core==1.30.1) (2.1.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\johealy\.conda\envs\pytorch_env\lib\site-packages (from requests>=2.21.0->azure-core==1.30.1) (2024.2.2)
# Requirement already satisfied: azure-search-documents==11.6.0b4 in c:\users\johealy\.conda\envs\pytorch_env\lib\site-packages (11.6.0b4)Note: you may need to restart the kernel to use updated packages.
#
# Requirement already satisfied: azure-core>=1.28.0 in c:\users\johealy\.conda\envs\pytorch_env\lib\site-packages (from azure-search-documents==11.6.0b4) (1.30.1)
# Requirement already satisfied: azure-common>=1.1 in c:\users\johealy\.conda\envs\pytorch_env\lib\site-packages (from azure-search-documents==11.6.0b4) (1.1.28)
# Requirement already satisfied: isodate>=0.6.0 in c:\users\johealy\.conda\envs\pytorch_env\lib\site-packages (from azure-search-documents==11.6.0b4) (0.6.1)
# Requirement already satisfied: requests>=2.21.0 in c:\users\johealy\.conda\envs\pytorch_env\lib\site-packages (from azure-core>=1.28.0->azure-search-documents==11.6.0b4) (2.31.0)
# Requirement already satisfied: six>=1.11.0 in c:\users\johealy\.conda\envs\pytorch_env\lib\site-packages (from azure-core>=1.28.0->azure-search-documents==11.6.0b4) (1.16.0)
# Requirement already satisfied: typing-extensions>=4.6.0 in c:\users\johealy\.conda\envs\pytorch_env\lib\site-packages (from azure-core>=1.28.0->azure-search-documents==11.6.0b4) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\johealy\.conda\envs\pytorch_env\lib\site-packages (from requests>=2.21.0->azure-core>=1.28.0->azure-search-documents==11.6.0b4) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\johealy\.conda\envs\pytorch_env\lib\site-packages (from requests>=2.21.0->azure-core>=1.28.0->azure-search-documents==11.6.0b4) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\johealy\.conda\envs\pytorch_env\lib\site-packages (from requests>=2.21.0->azure-core>=1.28.0->azure-search-documents==11.6.0b4) (2.1.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\johealy\.conda\envs\pytorch_env\lib\site-packages (from requests>=2.21.0->azure-core>=1.28.0->azure-search-documents==11.6.0b4) (2024.2.2)

# %% [markdown]
# Initial configuration for the notebook to run properly.

# %%
# Make sure paths are correct for the imports

import os
import sys

notebook_dir = os.path.abspath("")
parent_dir = os.path.dirname(notebook_dir)
grandparent_dir = os.path.dirname(parent_dir)


sys.path.append(grandparent_dir)

# %% [markdown]
# ### Configuring the Kernel
#
# Let's get started with the necessary configuration to run Semantic Kernel. For Notebooks, we require a `.env` file with the proper settings for the model you use. Create a new file named `.env` and place it in this directory. Copy the contents of the `.env.example` file from this directory and paste it into the `.env` file that you just created.
#
# **NOTE: Please make sure to include `GLOBAL_LLM_SERVICE` set to either OpenAI, AzureOpenAI, or HuggingFace in your .env file. If this setting is not included, the Service will default to AzureOpenAI.**
#
# #### Option 1: using OpenAI
#
# Add your [OpenAI Key](https://openai.com/product/) key to your `.env` file (org Id only if you have multiple orgs):
#
# ```
# GLOBAL_LLM_SERVICE="OpenAI"
# OPENAI_API_KEY="sk-..."
# OPENAI_ORG_ID=""
# OPENAI_CHAT_MODEL_ID=""
# OPENAI_TEXT_MODEL_ID=""
# OPENAI_EMBEDDING_MODEL_ID=""
# ```
# The names should match the names used in the `.env` file, as shown above.
#
# #### Option 2: using Azure OpenAI
#
# Add your [Azure Open AI Service key](https://learn.microsoft.com/azure/cognitive-services/openai/quickstart?pivots=programming-language-studio) settings to the `.env` file in the same folder:
#
# ```
# GLOBAL_LLM_SERVICE="AzureOpenAI"
# AZURE_OPENAI_API_KEY="..."
# AZURE_OPENAI_ENDPOINT="https://..."
# AZURE_OPENAI_CHAT_DEPLOYMENT_NAME="..."
# AZURE_OPENAI_TEXT_DEPLOYMENT_NAME="..."
# AZURE_OPENAI_EMBEDDING_DEPLOYMENT_NAME="..."
# AZURE_OPENAI_API_VERSION="..."
# ```
# The names should match the names used in the `.env` file, as shown above.
#
# For more advanced configuration, please follow the steps outlined in the [setup guide](./CONFIGURING_THE_KERNEL.md).

# %% [markdown]
# We will load our settings and get the LLM service to use for the notebook.

# %%
from services import Service

from samples.service_settings import ServiceSettings

service_settings = ServiceSettings()

# Select a service to use for this notebook (available services: OpenAI, AzureOpenAI, HuggingFace)
selectedService = (
    Service.AzureOpenAI
    if service_settings.global_llm_service is None
    else Service(service_settings.global_llm_service.lower())
)
print(f"Using service type: {selectedService}")
# Out:
# Using service type: Service.AzureOpenAI

# %% [markdown]
# In order to use memory, we need to instantiate the Kernel with a Memory Storage
# and an Embedding service. In this example, we make use of the `VolatileMemoryStore` which can be thought of as a temporary in-memory storage. This memory is not written to disk and is only available during the app session.
#
# When developing your app you will have the option to plug in persistent storage like Azure AI Search, Azure Cosmos Db, PostgreSQL, SQLite, etc. Semantic Memory allows also to index external data sources, without duplicating all the information as you will see further down in this notebook.

# %%
from semantic_kernel.connectors.ai.open_ai.services.azure_chat_completion import AzureChatCompletion
from semantic_kernel.connectors.ai.open_ai.services.azure_text_embedding import AzureTextEmbedding
from semantic_kernel.connectors.ai.open_ai.services.open_ai_chat_completion import OpenAIChatCompletion
from semantic_kernel.connectors.ai.open_ai.services.open_ai_text_embedding import OpenAITextEmbedding
from semantic_kernel.core_plugins.text_memory_plugin import TextMemoryPlugin
from semantic_kernel.kernel import Kernel
from semantic_kernel.memory.semantic_text_memory import SemanticTextMemory
from semantic_kernel.memory.volatile_memory_store import VolatileMemoryStore

kernel = Kernel()

chat_service_id = "chat"

# Configure AI service used by the kernel
if selectedService == Service.AzureOpenAI:
    azure_chat_service = AzureChatCompletion(
        service_id=chat_service_id,
    )
    # next line assumes embeddings deployment name is "text-embedding", adjust the deployment name to the value of your chat model if needed
    embedding_gen = AzureTextEmbedding(
        service_id="embedding",
    )
    kernel.add_service(azure_chat_service)
    kernel.add_service(embedding_gen)
elif selectedService == Service.OpenAI:
    oai_chat_service = OpenAIChatCompletion(
        service_id=chat_service_id,
    )
    embedding_gen = OpenAITextEmbedding(
        ai_model_id="embedding",
    )
    kernel.add_service(oai_chat_service)
    kernel.add_service(embedding_gen)

memory = SemanticTextMemory(storage=VolatileMemoryStore(), embeddings_generator=embedding_gen)
kernel.add_plugin(TextMemoryPlugin(memory), "TextMemoryPlugin")
# Out:
# KernelPlugin(name='TextMemoryPlugin', description=None, functions={'recall': KernelFunctionFromMethod(metadata=KernelFunctionMetadata(name='recall', plugin_name='TextMemoryPlugin', description='Recall a fact from the long term memory', parameters=[KernelParameterMetadata(name='ask', description='The information to retrieve', default_value=None, type_='str', is_required=True, type_object=<class 'str'>, schema_data={'type': 'string', 'description': 'The information to retrieve'}, function_schema_include=True), KernelParameterMetadata(name='collection', description='The collection to search for information.', default_value='generic', type_='str', is_required=False, type_object=<class 'str'>, schema_data={'type': 'string', 'description': 'The collection to search for information.'}, function_schema_include=True), KernelParameterMetadata(name='relevance', description='The relevance score, from 0.0 to 1.0; 1.0 means perfect match', default_value=0.75, type_='float', is_required=False, type_object=<class 'float'>, schema_data={'type': 'number', 'description': 'The relevance score, from 0.0 to 1.0; 1.0 means perfect match'}, function_schema_include=True), KernelParameterMetadata(name='limit', description='The maximum number of relevant memories to recall.', default_value=1, type_='int', is_required=False, type_object=<class 'int'>, schema_data={'type': 'integer', 'description': 'The maximum number of relevant memories to recall.'}, function_schema_include=True)], is_prompt=False, is_asynchronous=True, return_parameter=KernelParameterMetadata(name='return', description='', default_value=None, type_='str', is_required=True, type_object=<class 'str'>, schema_data={'type': 'string'}, function_schema_include=True), additional_properties={}), method=<bound method TextMemoryPlugin.recall of TextMemoryPlugin(memory=SemanticTextMemory(), embeddings_kwargs={})>, stream_method=None), 'save': KernelFunctionFromMethod(metadata=KernelFunctionMetadata(name='save', plugin_name='TextMemoryPlugin', description='Save information to semantic memory', parameters=[KernelParameterMetadata(name='text', description='The information to save.', default_value=None, type_='str', is_required=True, type_object=<class 'str'>, schema_data={'type': 'string', 'description': 'The information to save.'}, function_schema_include=True), KernelParameterMetadata(name='key', description='The unique key to associate with the information.', default_value=None, type_='str', is_required=True, type_object=<class 'str'>, schema_data={'type': 'string', 'description': 'The unique key to associate with the information.'}, function_schema_include=True), KernelParameterMetadata(name='collection', description='The collection to save the information.', default_value='generic', type_='str', is_required=False, type_object=<class 'str'>, schema_data={'type': 'string', 'description': 'The collection to save the information.'}, function_schema_include=True)], is_prompt=False, is_asynchronous=True, return_parameter=KernelParameterMetadata(name='return', description='', default_value=None, type_='None', is_required=False, type_object=None, schema_data={'type': 'object'}, function_schema_include=True), additional_properties={}), method=<bound method TextMemoryPlugin.save of TextMemoryPlugin(memory=SemanticTextMemory(), embeddings_kwargs={})>, stream_method=None)})

# %% [markdown]
# At its core, Semantic Memory is a set of data structures that allow you to store the meaning of text that come from different data sources, and optionally to store the source text too. These texts can be from the web, e-mail providers, chats, a database, or from your local directory, and are hooked up to the Semantic Kernel through data source connectors.
#
# The texts are embedded or compressed into a vector of floats representing mathematically the texts' contents and meaning. You can read more about embeddings [here](https://aka.ms/sk/embeddings).

# %% [markdown]
# ### Manually adding memories
#
# Let's create some initial memories "About Me". We can add memories to our `VolatileMemoryStore` by using `SaveInformationAsync`

# %%
collection_id = "generic"


async def populate_memory(memory: SemanticTextMemory) -> None:
    # Add some documents to the semantic memory
    await memory.save_information(collection=collection_id, id="info1", text="Your budget for 2024 is $100,000")
    await memory.save_information(collection=collection_id, id="info2", text="Your savings from 2023 are $50,000")
    await memory.save_information(collection=collection_id, id="info3", text="Your investments are $80,000")

# %%
await populate_memory(memory)

# %% [markdown]
# Let's try searching the memory:

# %%
async def search_memory_examples(memory: SemanticTextMemory) -> None:
    questions = [
        "What is my budget for 2024?",
        "What are my savings from 2023?",
        "What are my investments?",
    ]
    
    for question in questions:
        print(f"Question: {question}")
        result = await memory.search(collection_id, question)
        if result:
            print(f"Answer: {result[0].text}\n")
        else:
            print("No answer found.\n")

# %%
question = "What is my budget for 2024?"
result = await memory.search(collection_id, question)
if result:
    print(f"Answer: {result[0].text}\n")
else:
    print("No answer found.\n")
# Out:
# Collection 'generic' does not exist in collections:
# No answer found.

# %% [markdown]
# Let's now revisit the our chat sample from the [previous notebook](04-kernel-arguments-chat.ipynb).
# If you remember, we used kernel arguments to fill the prompt with a `history` that continuously got populated as we chatted with the bot. Let's add also memory to it!

# %% [markdown]
# This is done by using the `TextMemoryPlugin` which exposes the `recall` native function.
#
# `recall` takes an input ask and performs a similarity search on the contents that have
# been embedded in the Memory Store and returns the most relevant memory.

# %%
from semantic_kernel.functions import KernelFunction
from semantic_kernel.prompt_template import PromptTemplateConfig


async def setup_chat_with_memory(
    kernel: Kernel,
    service_id: str,
) -> KernelFunction:
    prompt = """
    ChatBot can have a conversation with you about any topic.
    It can give explicit instructions or say 'I don't know' if
    it does not have an answer.

    Information about me, from previous conversations:
    - {{recall 'budget by year'}} What is my budget for 2024?
    - {{recall 'savings from previous year'}} What are my savings from 2023?
    - {{recall 'investments'}} What are my investments?

    {{$request}}
    """.strip()

    prompt_template_config = PromptTemplateConfig(
        template=prompt,
        execution_settings={
            service_id: kernel.get_service(service_id).get_prompt_execution_settings_class()(service_id=service_id)
        },
    )

    return kernel.add_function(
        function_name="chat_with_memory",
        plugin_name="chat",
        prompt_template_config=prompt_template_config,
    )

# %% [markdown]
# The `RelevanceParam` is used in memory search and is a measure of the relevance score from 0.0 to 1.0, where 1.0 means a perfect match. We encourage users to experiment with different values.

# %% [markdown]
# Now that we've included our memories, let's chat!

# %%
print("Populating memory...")
await populate_memory(memory)

print("Asking questions... (manually)")
await search_memory_examples(memory)

print("Setting up a chat (with memory!)")
chat_func = await setup_chat_with_memory(kernel, chat_service_id)

print("Begin chatting (type 'exit' to exit):\n")
print(
    "Welcome to the chat bot!\
    \n  Type 'exit' to exit.\
    \n  Try asking a question about your finances (i.e. \"talk to me about my finances\")."
)


async def chat(user_input: str):
    print(f"User: {user_input}")
    answer = await kernel.invoke(chat_func, request=user_input)
    print(f"ChatBot:> {answer}")
# Out:
# Populating memory...
# Asking questions... (manually)
# Question: What is my budget for 2024?
# Answer: Your budget for 2024 is $100,000
#
# Question: What are my savings from 2023?
# Answer: Your savings from 2023 are $50,000
#
# Question: What are my investments?
# Answer: Your investments are $80,000
#
# Setting up a chat (with memory!)
# Begin chatting (type 'exit' to exit):
#
# Welcome to the chat bot!
#   Type 'exit' to exit.
#   Try asking a question about your finances (i.e. "talk to me about my finances").

# %%
await chat("What is my budget for 2024?")
# Out:
# User: What is my budget for 2024?
# ChatBot:> Your budget for 2024 is $100,000.

# %%
await chat("talk to me about my finances")
# Out:
# User: talk to me about my finances
# ChatBot:> Sure, let's talk about your finances! Based on the information you provided from our previous conversations, here's a summary:
#
# 1. **2024 Budget**: You have allocated a budget of $100,000 for the year 2024.
# 2. **2023 Savings**: You saved $50,000 in the year 2023.
# 3. **Investments**: Your current investments amount to $80,000.
#
# Would you like to discuss any specific aspect of your finances, such as budgeting strategies, investment options, or savings goals? Let me know how I can assist you further!

# %% [markdown]
# ### Adding documents to your memory
#
# Many times in your applications you'll want to bring in external documents into your memory. Let's see how we can do this using our VolatileMemoryStore.
#
# Let's first get some data using some of the links in the Semantic Kernel repo.

# %%
github_files = {}
github_files["https://github.com/microsoft/semantic-kernel/blob/main/README.md"] = (
    "README: Installation, getting started, and how to contribute"
)
github_files[
    "https://github.com/microsoft/semantic-kernel/blob/main/dotnet/notebooks/02-running-prompts-from-file.ipynb"
] = "Jupyter notebook describing how to pass prompts from a file to a semantic plugin or function"
github_files["https://github.com/microsoft/semantic-kernel/blob/main/dotnet/notebooks/00-getting-started.ipynb"] = (
    "Jupyter notebook describing how to get started with the Semantic Kernel"
)
github_files["https://github.com/microsoft/semantic-kernel/tree/main/samples/plugins/ChatPlugin/ChatGPT"] = (
    "Sample demonstrating how to create a chat plugin interfacing with ChatGPT"
)
github_files[
    "https://github.com/microsoft/semantic-kernel/blob/main/dotnet/src/SemanticKernel/Memory/Volatile/VolatileMemoryStore.cs"
] = "C# class that defines a volatile embedding store"

# %% [markdown]
# Now let's add these files to our VolatileMemoryStore using `SaveReferenceAsync`. We'll separate these memories from the chat memories by putting them in a different collection.

# %%
memory_collection_name = "SKGitHub"
print("Adding some GitHub file URLs and their descriptions to a volatile Semantic Memory.")

for index, (entry, value) in enumerate(github_files.items()):
    await memory.save_reference(
        collection=memory_collection_name,
        description=value,
        text=value,
        external_id=entry,
        external_source_name="GitHub",
    )
    print("  URL {} saved".format(index))
# Out:
# Adding some GitHub file URLs and their descriptions to a volatile Semantic Memory.
#   URL 0 saved
#   URL 1 saved
#   URL 2 saved
#   URL 3 saved
#   URL 4 saved

# %%
ask = "I love Jupyter notebooks, how should I get started?"
print("===========================\n" + "Query: " + ask + "\n")

memories = await memory.search(memory_collection_name, ask, limit=5, min_relevance_score=0.77)

for index, memory in enumerate(memories):
    print(f"Result {index}:")
    print("  URL:     : " + memory.id)
    print("  Title    : " + memory.description)
    print("  Relevance: " + str(memory.relevance))
    print()
# Out:
# ===========================
# Query: I love Jupyter notebooks, how should I get started?
#
# Result 0:
#   URL:     : https://github.com/microsoft/semantic-kernel/blob/main/dotnet/notebooks/00-getting-started.ipynb
#   Title    : Jupyter notebook describing how to get started with the Semantic Kernel
#   Relevance: 0.867669568629327
#
# Result 1:
#   URL:     : https://github.com/microsoft/semantic-kernel/blob/main/README.md
#   Title    : README: Installation, getting started, and how to contribute
#   Relevance: 0.8080048607377296
#
# Result 2:
#   URL:     : https://github.com/microsoft/semantic-kernel/blob/main/dotnet/notebooks/02-running-prompts-from-file.ipynb
#   Title    : Jupyter notebook describing how to pass prompts from a file to a semantic plugin or function
#   Relevance: 0.8019190676371464

# %% [markdown]
# Now you might be wondering what happens if you have so much data that it doesn't fit into your RAM? That's where you want to make use of an external Vector Database made specifically for storing and retrieving embeddings. Fortunately, semantic kernel makes this easy thanks to an extensive list of available connectors. In the following section, we will connect to an existing Azure AI Search service that we will use as an external Vector Database to store and retrieve embeddings.

# %% [markdown]
# _Please note you will need an AzureAI Search api_key or token credential and endpoint for the following example to work properly._

# %%
api_key = os.getenv("AZURE_AI_SEARCH_API_KEY")
endpoint = os.getenv("AZURE_AI_SEARCH_ENDPOINT")

# %%
from semantic_kernel.connectors.memory.azure_cognitive_search import AzureCognitiveSearchMemoryStore

acs_memory_store = AzureCognitiveSearchMemoryStore(vector_size=1536, admin_key=api_key, search_endpoint=endpoint)

memory = SemanticTextMemory(storage=acs_memory_store, embeddings_generator=embedding_gen)
kernel.add_plugin(TextMemoryPlugin(memory), "TextMemoryPluginACS")
# Out:
# ---------------------------------------------------------------------------
# ValidationError                           Traceback (most recent call last)
# File c:\Users\johealy\.conda\envs\pytorch_env\Lib\site-packages\semantic_kernel\connectors\memory\azure_cognitive_search\azure_cognitive_search_memory_store.py:80, in AzureCognitiveSearchMemoryStore.__init__(self, vector_size, search_endpoint, admin_key, azure_credentials, token_credentials, env_file_path, env_file_encoding)
#      79 try:
# ---> 80     acs_memory_settings = AzureAISearchSettings.create(
#      81         env_file_path=env_file_path,
#      82         endpoint=search_endpoint,
#      83         api_key=admin_key,
#      84         env_file_encoding=env_file_encoding,
#      85     )
#      86 except ValidationError as exc:
#
# File c:\Users\johealy\.conda\envs\pytorch_env\Lib\site-packages\semantic_kernel\kernel_pydantic.py:56, in KernelBaseSettings.create(cls, **data)
#      55 data = {k: v for k, v in data.items() if v is not None}
# ---> 56 return cls(**data)
#
# File c:\Users\johealy\.conda\envs\pytorch_env\Lib\site-packages\pydantic_settings\main.py:140, in BaseSettings.__init__(__pydantic_self__, _case_sensitive, _env_prefix, _env_file, _env_file_encoding, _env_ignore_empty, _env_nested_delimiter, _env_parse_none_str, _env_parse_enums, _cli_prog_name, _cli_parse_args, _cli_settings_source, _cli_parse_none_str, _cli_hide_none_type, _cli_avoid_json, _cli_enforce_required, _cli_use_class_docs_for_groups, _cli_prefix, _secrets_dir, **values)
#     117 def __init__(
#     118     __pydantic_self__,
#     119     _case_sensitive: bool | None = None,
#    (...)
#     138 ) -> None:
#     139     # Uses something other than `self` the first arg to allow "self" as a settable attribute
# --> 140     super().__init__(
#     141         **__pydantic_self__._settings_build_values(
#     142             values,
#     143             _case_sensitive=_case_sensitive,
#     144             _env_prefix=_env_prefix,
#     145             _env_file=_env_file,
#     146             _env_file_encoding=_env_file_encoding,
#     147             _env_ignore_empty=_env_ignore_empty,
#     148             _env_nested_delimiter=_env_nested_delimiter,
#     149             _env_parse_none_str=_env_parse_none_str,
#     150             _env_parse_enums=_env_parse_enums,
#     151             _cli_prog_name=_cli_prog_name,
#     152             _cli_parse_args=_cli_parse_args,
#     153             _cli_settings_source=_cli_settings_source,
#     154             _cli_parse_none_str=_cli_parse_none_str,
#     155             _cli_hide_none_type=_cli_hide_none_type,
#     156             _cli_avoid_json=_cli_avoid_json,
#     157             _cli_enforce_required=_cli_enforce_required,
#     158             _cli_use_class_docs_for_groups=_cli_use_class_docs_for_groups,
#     159             _cli_prefix=_cli_prefix,
#     160             _secrets_dir=_secrets_dir,
#     161         )
#     162     )
#
# File c:\Users\johealy\.conda\envs\pytorch_env\Lib\site-packages\pydantic\main.py:193, in BaseModel.__init__(self, **data)
#     192 __tracebackhide__ = True
# --> 193 self.__pydantic_validator__.validate_python(data, self_instance=self)
#
# ValidationError: 1 validation error for AzureAISearchSettings
# endpoint
#   Field required [type=missing, input_value={'azure_openai_chat_deplo...rch.search.windows.net'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
#
# The above exception was the direct cause of the following exception:
#
# MemoryConnectorInitializationError        Traceback (most recent call last)
# Cell In[17], line 3
#       1 from semantic_kernel.connectors.memory.azure_cognitive_search import AzureCognitiveSearchMemoryStore
# ----> 3 acs_memory_store = AzureCognitiveSearchMemoryStore(vector_size=1536, admin_key=api_key, search_endpoint=endpoint)
#       5 memory = SemanticTextMemory(storage=acs_memory_store, embeddings_generator=embedding_gen)
#       6 kernel.add_plugin(TextMemoryPlugin(memory), "TextMemoryPluginACS")
#
# File c:\Users\johealy\.conda\envs\pytorch_env\Lib\site-packages\semantic_kernel\connectors\memory\azure_cognitive_search\azure_cognitive_search_memory_store.py:87, in AzureCognitiveSearchMemoryStore.__init__(self, vector_size, search_endpoint, admin_key, azure_credentials, token_credentials, env_file_path, env_file_encoding)
#      80     acs_memory_settings = AzureAISearchSettings.create(
#      81         env_file_path=env_file_path,
#      82         endpoint=search_endpoint,
#      83         api_key=admin_key,
#      84         env_file_encoding=env_file_encoding,
#      85     )
#      86 except ValidationError as exc:
# ---> 87     raise MemoryConnectorInitializationError("Failed to create Azure Cognitive Search settings.") from exc
#      89 self._vector_size = vector_size
#      90 self._search_index_client = get_search_index_async_client(
#      91     search_endpoint=str(acs_memory_settings.endpoint),
#      92     admin_key=acs_memory_settings.api_key.get_secret_value() if acs_memory_settings.api_key else None,
#      93     azure_credential=azure_credentials,
#      94     token_credential=token_credentials,
#      95 )
#
# MemoryConnectorInitializationError: Failed to create Azure Cognitive Search settings.
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %% [markdown]
# The implementation of Semantic Kernel allows to easily swap memory store for another. Here, we will re-use the functions we initially created for `VolatileMemoryStore` with our new external Vector Store leveraging Azure AI Search

# %%
await populate_memory(memory)

# %% [markdown]
# Let's now try to query from Azure AI Search!

# %%
await search_memory_examples(memory)

# %% [markdown]
# We have laid the foundation which will allow us to store an arbitrary amount of data in an external Vector Store above and beyond what could fit in memory at the expense of a little more latency.
